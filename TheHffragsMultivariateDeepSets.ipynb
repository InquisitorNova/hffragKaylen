# %%
"""
*Filename: SecondaryVertexDeepSetTrainer
*Description: This jupyter notebook is an extension of the ProjectorTrainer, it trains the same
*residual deep sets neural network architecture as the projector trainer with the additional
*features as well. In addition it adds the secondary vertex displacement of the b_jets as an
*additional target for the network to converge to.
Date: 16/02/2023
Author: Kaylen Smith Darnbrook
"""
# Import relevant modules
import os
import numpy as np
import seaborn as sns
import wandb
#from wandb.keras import WandbCallback
from keras import callbacks
import keras
import DeepSetNeuralNetArchitecture as DSNNA
from DeepSetNeuralNetArchitecture import LogNormal_Loss_Function
from DeepSetNeuralNetArchitecture import Mean_Squared_Error
from HffragDeepSetsProjectionMultivariate import DeepSetsProjection
from sklearn.feature_selection import mutual_info_regression
import keras.backend as k
import uproot
import awkward as ak
import sklearn as sk
from numpy.lib.recfunctions import structured_to_unstructured
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
import pandas as pd
from hffrag import fixedbinning
from hffrag import binneddensity
from keras.utils.vis_utils import plot_model
from timeit import default_timer as timer
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Format the style and format of the matplotlib plots
plt.style.use("default")
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['savefig.facecolor'] = 'white'
plt.rc('text',usetex = False)
plt.rc('font',family = 'Times New Roman')

# %%
# The data is being stored in a tree datastructure.
# We access the charm root using this command
tree = uproot.open("/storage/epp2/phswmv/data/hffrag/hffrag.root:CharmAnalysis")

# %%
# Initial parameters
MASKVAL = -999 # This value is introduced to ensure arrays are regular (Of the same size). They will be masked later by the network
MAXTRACKS = 32 # This value is the maximum number of tracks allowed per event
BATCHSIZE = 64 # This is the batch size of the mini batches used during training
EPOCHS = 1000  # This is the default number of epochs for which the neural network will train providing that early stopping does not occur
MAXEVENTS = 2e5 #This is the maximum number of events that will the program will accept
LR = 3e-4 #This is the default learning rate

# %%
# Select the features we wish to study
track_features = ["AnalysisTracks_pt", "AnalysisTracks_eta", "AnalysisTracks_phi", "AnalysisTracks_z0sinTheta",
                   "AnalysisTracks_d0sig", "AnalysisTracks_d0", "AnalysisTracks_d0sigPV", "AnalysisTracks_d0PV"]
jet_features = ["AnalysisAntiKt4TruthJets_pt", "AnalysisAntiKt4TruthJets_eta", "AnalysisAntiKt4TruthJets_phi", "AnalysisAntiKt4TruthJets_m","AnalysisAntiKt4TruthJets_ghostB_pdgId",
                "AnalysisAntiKt4TruthJets_ghostB_pt", "AnalysisAntiKt4TruthJets_ghostB_eta","AnalysisAntiKt4TruthJets_ghostB_phi", "AnalysisAntiKt4TruthJets_ghostB_m"]
Electrons_features = ["AnalysisElectrons_pt_NOSYS","AnalysisElectrons_eta", "AnalysisElectrons_phi", "AnalysisElectrons_z0sinTheta", 
                    "AnalysisElectrons_d0sig", "AnalysisElectrons_d0", "AnalysisElectrons_d0sigPV", "AnalysisElectrons_d0PV"]
Muon_Features = ["AnalysisMuons_pt_NOSYS", "AnalysisMuons_eta", "AnalysisMuons_phi","AnalysisMuons_z0sinTheta", 
                    "AnalysisMuons_d0sig", "AnalysisMuons_d0", "AnalysisMuons_d0sigPV", "AnalysisMuons_d0PV"]

# %%
# Read in the data from the root file
features = tree.arrays(jet_features+track_features + Electrons_features + Muon_Features, entry_stop=MAXEVENTS)

# %%
# Select the events of interest
events = features[ak.sum(
    features["AnalysisAntiKt4TruthJets_pt"] > 25000, axis=1) > 0]

# %%
# Displays the number of jets being trained on
jets = events[jet_features][:,0]
print("The number of jets to train on is: ", len(jets))
print("The number of track features is: ",len(track_features))
# Out:
# The number of jets to train on is:  199840
# The number of track features is:  8

# %%
# Select tracks from the events
tracks = events[track_features]
electrons = events[Electrons_features]
muons = events[Muon_Features]

# Match the tracks to the jets
mask_tracks = DSNNA.Match_Tracks(jets, tracks)
mask_electrons = DSNNA.Match_Electrons(jets,electrons)
mask_muons = DSNNA.Match_Muons(jets,muons)
matchedtracks = tracks[mask_tracks]
matchedelectrons = electrons[mask_electrons]
matchedmuons = muons[mask_muons]

# Pad and Flatten the data
matchedtracks = DSNNA.flatten(matchedtracks, MAXTRACKS)
matchedelectrons = DSNNA.flatten(matchedelectrons, MAXTRACKS)
matchedmuons = DSNNA.flatten(matchedmuons, MAXTRACKS)

# %%
#Selects the b-jets with bhadrons with a transverse momentum over 5000 MeV
bjets = ak.sum(jets["AnalysisAntiKt4TruthJets_ghostB_pt"] > 5000, axis=1) > 0
jets = jets[bjets]

# Obtain the pt, eta and phi of each b hadron jet
bhads_pt = jets["AnalysisAntiKt4TruthJets_ghostB_pt"][:, 0].to_numpy()
bhads_eta = jets["AnalysisAntiKt4TruthJets_ghostB_eta"][:,0].to_numpy()
bhads_phi = jets["AnalysisAntiKt4TruthJets_ghostB_phi"][:,0].to_numpy()
bhads_m = jets["AnalysisAntiKt4TruthJets_ghostB_m"][:,0].to_numpy()
bhads_PGID = jets["AnalysisAntiKt4TruthJets_ghostB_pdgId"][:,0].to_numpy()

jets_pt = jets["AnalysisAntiKt4TruthJets_pt"].to_numpy()
jets_eta = jets["AnalysisAntiKt4TruthJets_eta"].to_numpy()
jets_phi = jets["AnalysisAntiKt4TruthJets_phi"].to_numpy()
jets_m = jets["AnalysisAntiKt4TruthJets_m"].to_numpy()
b_jets = np.stack([jets_pt,jets_eta,jets_phi, jets_m], axis = -1)

bhads = np.stack([bhads_pt,bhads_eta,bhads_phi, bhads_m],axis = -1) #Combine the momentum, eta and phi for each jet into one array

print("There are {} outputs".format(np.shape(bhads)[1])) # Display the number of target features the neural network will predict
matchedtracks = matchedtracks[bjets]
matchedelectrons = matchedelectrons[bjets]
matchedmuons = matchedmuons[bjets]
print("There are {} tracks inputs".format(np.shape(matchedtracks)[1])) # Display the number of target features the neural network will use in it's predictions
print("There are {} electrons inputs".format(np.shape(matchedelectrons)[1])) # Display the number of target features the neural network will use in it's predictions
print("There are {} muons inputs".format(np.shape(matchedmuons)[1])) # Display the number of target features the neural network will use in it's predictions
# Out:
# There are 4 outputs
# There are 32 tracks inputs
# There are 32 electrons inputs
# There are 32 muons inputs

# %%
# Transform the jet and tracks to unstructed data.
jets = structured_to_unstructured(jets[jet_features[:-5]])
matchedtracks = structured_to_unstructured(matchedtracks)
matchedelectrons  = structured_to_unstructured(matchedelectrons)
matchedmuons = structured_to_unstructured(matchedmuons)

# %%
# Convert the coordinates of the b jets and tracks to cartesian coordinates
polartracks = matchedtracks.to_numpy()
polarelectrons = matchedelectrons.to_numpy()
polarmuons = matchedmuons.to_numpy()

Num_events = MAXTRACKS
tracks_pt = polartracks[:,:,0].reshape(-1,Num_events,1)
tracks_eta = polartracks[:,:,1].reshape(-1,Num_events,1)
tracks_phi = polartracks[:,:,2].reshape(-1,Num_events,1)

tracks_pep = np.concatenate([tracks_pt,tracks_eta,tracks_phi], axis = -1) 
print(tracks_pep.shape)

electrons_pt = polarelectrons[:,:,0].reshape(-1,Num_events,1)
electrons_eta = polarelectrons[:,:,1].reshape(-1,Num_events,1)
electrons_phi = polarelectrons[:,:,2].reshape(-1,Num_events,1)

electrons_pep = np.concatenate([electrons_pt,electrons_eta,electrons_phi], axis = -1) 
print(electrons_pep.shape)

muons_pt = polarmuons[:,:,0].reshape(-1,Num_events,1)
muons_eta = polarmuons[:,:,1].reshape(-1,Num_events,1)
muons_phi = polarmuons[:,:,2].reshape(-1,Num_events,1)

muons_pep = np.concatenate([muons_pt,muons_eta,muons_phi], axis = -1) 
print(muons_pep.shape)

jets_pt = b_jets[:,0].reshape(-1,1)
jets_eta = b_jets[:,1].reshape(-1,1)
jets_phi = b_jets[:,2].reshape(-1,1)

b_jets_pep = np.concatenate([jets_pt,jets_eta,jets_phi], axis = -1) 
print(b_jets_pep.shape)

tracks_p = DSNNA.pt_eta_phi_2_px_py_pz_tracks(matchedtracks.to_numpy())
electrons_p = DSNNA.pt_eta_phi_2_px_py_pz_tracks(matchedelectrons.to_numpy())
muons_p = DSNNA.pt_eta_phi_2_px_py_pz_tracks(matchedmuons.to_numpy())

bhads = DSNNA.pt_eta_phi_2_px_py_pz_jets(bhads)
b_jets_p = DSNNA.pt_eta_phi_2_px_py_pz_jets(b_jets)
b_jets_m = b_jets[:,-1].reshape(-1,1)

#Combine the momenta of the tracks with the rest of the track features to form the track dataset
tracks = np.concatenate([tracks_p,tracks_pep,matchedtracks[:,:,3:].to_numpy()],axis = 2)
electrons = np.concatenate([electrons_p, electrons_pep, matchedelectrons[:,:,3:].to_numpy()], axis = 2)
muons = np.concatenate([muons_p, muons_pep, matchedmuons[:,:,3:].to_numpy()], axis = 2)

print(np.shape(tracks), np.shape(electrons), np.shape(muons))
particles = np.concatenate([tracks,electrons,muons], axis = 1)
b_jets = np.concatenate([b_jets_p,b_jets_pep,b_jets_m] ,axis = 1)
# Out:
# (96659, 32, 3)
# (96659, 32, 3)
# (96659, 32, 3)
# (96659, 3)
# /home/physics/phujdj/DeepLearningParticlePhysics/DeepSetNeuralNetArchitecture.py:146: RuntimeWarning: overflow encountered in sinh
#   pzs = np.where(mask1 | mask3, pts, pts * np.sinh(etas))
# (96659, 32, 11) (96659, 32, 11) (96659, 32, 11)

# %%
np.shape(particles)
# Out:
# (96659, 96, 11)

# %%
#Mask out the MASKVALs used to pad the arrays
particles = np.ma.masked_values(particles,-999)

# %%
#Calculate the fraction of the momenta that
# the bhadrons represent of the b_jet momenta
bhads_fractions_px = bhads[:,0]/b_jets[:,0]
bhads_fractions_py = bhads[:,1]/b_jets[:,1]
bhads_fractions_pz = bhads[:,2]/b_jets[:,2]
print(bhads_fractions_px.shape)
# Out:
# (96659,)

# %%
# Calculate the magnitude of the b_jets momenta and 
# use it to calculate the projection of the bhadron momenta along the 
# b_jet momenta
b_jets_mag = np.linalg.norm(b_jets[:,:3], axis = 1)
bhads_fractions = np.stack([bhads_fractions_px,bhads_fractions_py, bhads_fractions_pz], axis = -1)
bhads_projection = ((bhads[:,:3]*b_jets[:,:3]).sum(axis = 1))/(b_jets_mag**2)
print(bhads_fractions.shape)
# Out:
# (96659, 3)

# %%
#Creates an approximate track momentum and 4 momentum for the network to use.
particles_Momentum = np.sqrt(particles[:, : ,0]**2 + particles[:,:,1]**2 + particles[:,:,2]**2)
particles_4_Momentum = np.stack([particles_Momentum, particles[:,:,0], particles[:,:,1], particles[:,:,2]], axis = -1)
print(particles_4_Momentum.shape)
# Out:
# /tmp/ipykernel_8371/4078472412.py:2: RuntimeWarning: invalid value encountered in sqrt
#   particles_Momentum = np.sqrt(particles[:, : ,0]**2 + particles[:,:,1]**2 + particles[:,:,2]**2)
# (96659, 96, 4)

# %%
#Creates a very approximate track mass for the network to use.
particles_Invariant_Mass = np.sqrt((np.sum(particles_4_Momentum, axis = 1) * np.sum(particles_4_Momentum, axis = 1)).sum(axis = -1))
print(particles_Invariant_Mass.shape)
# Out:
# (96659,)

# %%
#From the base features for the tracks and jet provided by the roots 
#file calculate the derived features needed for convergence.
#These features were inspired from reading on current particle physics literature
b_jets_mag = np.linalg.norm(b_jets[:,:3], axis = 1)
bhads_mag = np.linalg.norm(bhads[:,:3], axis = 1)
particles_Momentum = np.sum(np.linalg.norm(particles[:,:,:3], axis = 2))

bhads_fractions_px = bhads[:,0]/b_jets[:,0]
bhads_fractions_py = bhads[:,1]/b_jets[:,1]
bhads_fractions_pz = bhads[:,2]/b_jets[:,2]
bhads_fractions_pt = bhads_pt/b_jets_pep[:,0]
print(bhads_fractions_px.shape)

b_jets_energy = np.sqrt((b_jets_m[:,0]**2) + (b_jets_mag**2))
print(b_jets_energy.shape, b_jets_m.shape)

b_jets_energy_pt = np.sqrt((b_jets_m[:,0]**2) + (b_jets[:,4]**2))
b_jets_energy_pt.shape


b_jet_energy_mass_ratio = b_jets_energy/b_jets_m[:,0]
b_jet_energy_mass_ratio[np.isinf(b_jet_energy_mass_ratio)] = np.median(b_jet_energy_mass_ratio)


print(b_jet_energy_mass_ratio.shape)
bhads_energy = np.sqrt((bhads_m**2) + (bhads_mag**2))
bhads_energy.shape

bhads_energy_mass_ratio = bhads_energy/bhads_m

print(bhads_fractions[0])
print(bhads[0,0]/b_jets[0,0])
print(np.min(bhads_fractions),np.max(bhads_fractions))

print(bhads_fractions_px[0])
print(bhads[0,0]/b_jets[0,0])
print(np.min(bhads_fractions_px),np.max(bhads_fractions_px))

print("Hello")
sum_px_particles = np.sum(particles[:,:,0], axis = 1)
sum_py_particles = np.sum(particles[:,:,1], axis = 1)
sum_pz_particles = np.sum(particles[:,:,2], axis = 1)
sum_pt_particles = np.sum(particles[:,:,3], axis = 1)
print(sum_pt_particles.shape)

sum_px_particles_RSE = np.sqrt(np.sum(particles[:,:,0]**2, axis = 1))
sum_py_particles_RSE= np.sqrt(np.sum(particles[:,:,1]**2, axis = 1))
sum_pz_particles_RSE = np.sqrt(np.sum(particles[:,:,2]**2, axis = 1))
sum_pt_particles_RSE = np.sqrt(np.sum(particles[:,:,3]**2, axis = 1))
print(sum_pt_particles_RSE.shape)

RSM_scaled_px = sum_px_particles_RSE/sum_px_particles
RSM_scaled_py = sum_py_particles_RSE/sum_py_particles
RSM_scaled_pz = sum_pz_particles_RSE/sum_pz_particles
RSM_scaled_pt = sum_pt_particles_RSE/sum_pt_particles
print(RSM_scaled_pt.shape)

RMS_scaled_px = np.sqrt(np.sum(particles[:,:,0]**2, axis = 1)/MAXTRACKS)
RMS_scaled_py = np.sqrt(np.sum(particles[:,:,1]**2, axis = 1)/MAXTRACKS)
RMS_scaled_pz = np.sqrt(np.sum(particles[:,:,2]**2, axis = 1)/MAXTRACKS)
RMS_scaled_pt = np.sqrt(np.sum(particles[:,:,3]**2, axis = 1)/MAXTRACKS)
print(RMS_scaled_pt.shape)

Log_px_particles = np.log(abs(particles[:,:,0]/b_jets[:,np.newaxis,0]))
Log_py_particles = np.log(abs(particles[:,:,1]/b_jets[:,np.newaxis,1]))
Log_pz_particles = np.log(abs(particles[:,:,2]/b_jets[:,np.newaxis,2]))
Log_pt_particles = np.log(abs(particles[:,:,3]/b_jets[:,np.newaxis,3]))
Log_particles = np.stack([Log_px_particles, Log_py_particles, Log_pz_particles, Log_pt_particles], axis = -1)

Log_Sum_px = np.log(sum_px_particles/b_jets[:,0])
Log_Sum_py = np.log(sum_py_particles/b_jets[:,1])
Log_Sum_pz = np.log(sum_pz_particles/b_jets[:,2])
Log_Sum_pt = np.log(sum_pt_particles/b_jets[:,3])
Log_Momenta = np.log(abs(particles_Momentum/np.sum(b_jets[:,:3], axis = 1)))
print(Log_Sum_pt.shape)

particles_fractions_px = particles[:,:,0]/b_jets[:,np.newaxis,0]
particles_fractions_py = particles[:,:,1]/b_jets[:,np.newaxis,1]
particles_fractions_pz = particles[:,:,2]/b_jets[:,np.newaxis,2]
particles_fractions_pt = particles[:,:,3]/b_jets[:,np.newaxis,3]
print(particles_fractions_pt.shape)
particles_fractions = np.stack([particles_fractions_px,particles_fractions_py, particles_fractions_pz], axis = -1)
print(particles_fractions.shape)

print(particles_fractions.shape)
print(particles[0,0,0]/b_jets[0,0])
print(np.mean(particles_fractions),np.std(particles_fractions))

particles_projection = ((particles[:,:,:3]*b_jets[:,np.newaxis,:3]).sum(axis = 2)/(b_jets_mag[:,np.newaxis]**2))
print(particles_projection.shape)
particles_Momenta = np.stack([sum_px_particles, sum_py_particles, sum_pz_particles], axis = -1)
print(particles_Momenta.shape)
Sum_particles_projection = ((particles_Momenta*b_jets[:,:3]).sum(axis = 1))/(b_jets_mag**2)
print(Sum_particles_projection.shape)

b_jet_energy_ratio_px = sum_px_particles/b_jets_energy
b_jet_energy_ratio_py = sum_py_particles/b_jets_energy
b_jet_energy_ratio_pz = sum_pz_particles/b_jets_energy
b_jet_energy_ratio_pt = sum_pt_particles/b_jets_energy
print(b_jet_energy_ratio_pt.shape)

b_jet_energy_ratio_cart = b_jets_mag/b_jets_energy
b_jet_energy_ratio_pt = b_jets[:,4]/b_jets_energy
print(b_jet_energy_ratio_pt.shape)

b_jet_energy_ratio_total = np.sum(b_jets[:,4])/np.sum(b_jets_energy)  
b_jet_transverse_mass = np.sqrt(b_jets_energy**2 - b_jets[:,2]**2)
bhads_transverse_mass = np.sqrt(bhads_energy**2 - bhads[:,2]**2)
print(b_jet_transverse_mass[0])
print(b_jet_energy_ratio_total.shape)
print(b_jet_transverse_mass.shape)
print(np.full((len(b_jets)),b_jet_energy_ratio_total).shape)
bhads_projection = ((bhads[:,:3]*b_jets[:,:3]).sum(axis = 1))/(b_jets_mag**2)

print(np.mean(b_jets_energy),np.std(b_jets_energy))
b_jets = np.stack([b_jets[:,0], b_jets[:,1], b_jets[:,2],b_jets[:,3],b_jets[:,4], b_jets[:,5], b_jets[:,6], b_jets_mag, sum_px_particles, sum_py_particles, sum_pz_particles, sum_pt_particles, sum_px_particles_RSE, sum_py_particles_RSE, sum_pz_particles_RSE, sum_pt_particles_RSE, RSM_scaled_px, RSM_scaled_py, RSM_scaled_pz, RSM_scaled_pt, RMS_scaled_px, RMS_scaled_py, RMS_scaled_pz, RMS_scaled_pt, b_jet_transverse_mass, Log_Sum_px, Log_Sum_py, Log_Sum_pz, Log_Sum_pt, Log_Momenta, b_jets_energy, b_jet_energy_ratio_px, b_jet_energy_ratio_py, b_jet_energy_ratio_pz, b_jet_energy_ratio_cart, b_jet_energy_ratio_pt, b_jet_energy_mass_ratio, np.full((len(b_jets),),b_jet_energy_ratio_total)], axis = -1)
bhads_targets = np.stack([bhads[:,0]/1e6,bhads[:,1]/1e6, bhads[:,2]/1e6,bhads_pt/1e6, bhads_eta, bhads_phi, bhads_energy/1e6, bhads_fractions_pt, bhads_projection], axis = -1)
# Out:
# (96659,)
# (96659,) (96659, 1)
# (96659,)
# [0.9923946  1.00824593 0.99120818]
# 0.9923945992521676
# -34465.39587820514 618.1237235802715
# 0.9923945992521676
# 0.9923945992521676
# -4195.466731248074 618.1237235802715
# Hello
# /tmp/ipykernel_8371/772223639.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   b_jet_energy_mass_ratio = b_jets_energy/b_jets_m[:,0]
# (96659,)
# (96659,)
# (96659,)
# (96659,)
# /tmp/ipykernel_8371/772223639.py:70: RuntimeWarning: divide by zero encountered in log
#   Log_Sum_px = np.log(sum_px_particles/b_jets[:,0])
# /tmp/ipykernel_8371/772223639.py:70: RuntimeWarning: invalid value encountered in log
#   Log_Sum_px = np.log(sum_px_particles/b_jets[:,0])
# /tmp/ipykernel_8371/772223639.py:71: RuntimeWarning: divide by zero encountered in log
#   Log_Sum_py = np.log(sum_py_particles/b_jets[:,1])
# /tmp/ipykernel_8371/772223639.py:71: RuntimeWarning: invalid value encountered in log
#   Log_Sum_py = np.log(sum_py_particles/b_jets[:,1])
# /tmp/ipykernel_8371/772223639.py:72: RuntimeWarning: divide by zero encountered in log
#   Log_Sum_pz = np.log(sum_pz_particles/b_jets[:,2])
# /tmp/ipykernel_8371/772223639.py:72: RuntimeWarning: invalid value encountered in log
#   Log_Sum_pz = np.log(sum_pz_particles/b_jets[:,2])
# /tmp/ipykernel_8371/772223639.py:73: RuntimeWarning: divide by zero encountered in log
#   Log_Sum_pt = np.log(sum_pt_particles/b_jets[:,3])
# (96659,)
# (96659, 96)
# (96659, 96, 3)
# (96659, 96, 3)
# 0.14894195156291137
# -889.5405690026124 312.0555330470199
# (96659, 96)
# (96659, 3)
# (96659,)
# (96659,)
# (96659,)
# 79564.74
# ()
# (96659,)
# (96659,)
# 215380.48 189104.06

# %%
np.min(b_jets),np.max(b_jets)
# Out:
# (-23884111.203433707, 31619725.805484924)

# %%
np.min(bhads_targets), np.max(bhads_targets)
# Out:
# (-4.542725086212158, 4.581223011016846)

# %%
"""
0 - Momentum Px Scaled
1 - Momentum Py Scaled
2 - Momentum Pz Scaled
3-  Momentum Pt Scaled
4-  Momentum Eta Scaled
5 - Momentum Phi Scaled
6 - Tranvserse Impact parameter sin component
7 - Longitudinal Impact parameter
8 - Longitudinal Impact parameter signficiance
9 - Longitudinal Impact Parameter w.r.t PV
10 - Longitudinal Impact Parameter wr.r.t PV
11 - Momentum Fraction Px Scaled
12 - Momentum Fraction Py Scaled
13 - Momentum Fraction Pz Scaled
14 - Momentum Fraction pt Scaled.
15 - Logarithm of px of the tracks / b_jet x momenta
16 - Logarithm of py of the tracks / b_jet y momenta
17 - Logarithm of pz of the tracks / b_jet z momenta
18 - Logarithm of sum pt of the tracks / b_jet t momenta
"""
#Combine the features into one array
particles_input = np.concatenate([particles, Log_particles], axis = -1)
print(particles_input.shape)
# Out:
# (96659, 96, 15)

# %%
"""
0 - Momentum Px Scaled
1 - Momentum Py Scaled
2 - Momentum Pz Scaled
3 - Momentum Pt Scaled
4 - Momentum eta Scaled
5 - Momentum Phi Scaled
6 - Sum px of the tracks
7 - Sum py of the tracks
8 - Sum pz of the tracks
9 - Sum pt of the tracks
10 - Sqrt of the Sum px of the tracks
11 - Sqrt of the Sum py of the tracks
12 - Sqrt of the Sum pz of the tracks
13 - Sqrt of the Sum pt of the tracks
14 - Sqrt of the Sum px of the tracks scaled by the sum px of the tracks
15 - Sqrt of the Sum py of the tracks scaled by the sum py of the tracks
16 - Sqrt of the Sum pz of the tracks scaled by the sum pz of the tracks
17 - Sqrt of the Sum pt of the tracks scaked by the sum pt of the tracks
18 - Root Mean Square of the px momenta of the tracks
19 - Root Mean Square of the py momenta of the tracks
20 - Root Mean Square of the pz momenta of the tracks
21 - Root Mean Square of the pt momenta of the tracks
22 - Tranvserse mass of the b-jets
23 - Logarithm of the  Sum px of the tracks divide by the b_jet x momenta
24 - Logarithm of the  Sum py of the tracks divide by the b_jet y momenta
25 - Logarithm of the  Sum pz of the tracks divide by the b_jet z momenta
26 - Logarithm of the total momenta of the tracks divided by the b_jet total momenta
27 - B_jet energy
28 - B_jet energy ratio px
29 - B_jet energy ratio py
30 - B_jet energy ratio pz
31 - B_jet energy ratio pt
32 - B_jet energy ratio cart
32 - B_jet energy ratio pt
33 - B_jet energy ratio total
"""
#Combine the features into an array
b_jets_input = np.concatenate([b_jets, particles_projection, Sum_particles_projection.reshape(-1,1)], axis = -1)
print(b_jets_input.shape)
# Out:
# (96659, 135)

# %%
from collections import Counter
counter = Counter(bhads_PGID)
print(counter)
# Out:
# Counter({511: 20748, -521: 20663, -511: 20551, 521: 20534, 531: 4693, -531: 4656, 5122: 1893, -5122: 1848, 5132: 278, 5232: 267, -5132: 261, -5232: 250, 5332: 6, -5332: 6, -541: 4, 555: 1})

# %%
from sklearn.preprocessing import OneHotEncoder
counter = np.array([])
bhadron_PGIDs = []
for PGID in bhads_PGID:
    if (PGID == 521 or PGID == -521):
        element = 0
    elif (PGID == 511 or PGID == -511):
        element = 1
    else:
        element = 2
    counter = np.append(counter, [element])
    bhadron_PGIDs.append([str(element)])
print(np.shape(bhadron_PGIDs))
counter = Counter(counter)
print(counter)
encoder = OneHotEncoder(sparse = False)
onehot = encoder.fit_transform(bhadron_PGIDs)
print(np.shape(onehot))
# Out:
# (96659, 1)
# Counter({1.0: 41299, 0.0: 41197, 2.0: 14163})
# (96659, 3)

# %%
Scaler_particles = StandardScaler()
Num_events,Num_tracks,Num_features = np.shape(particles_input)
Scaled_particles = np.reshape(particles_input, newshape=(-1,Num_features))
particles_scaled = Scaler_particles.fit_transform(Scaled_particles)
particles_input_scaled = np.reshape(particles_scaled, newshape= (Num_events,Num_tracks,Num_features))
print(np.shape(particles_input_scaled))

Scaler_jets = StandardScaler()
Num_events,Num_features = np.shape(b_jets_input)
b_jets_scaled = np.reshape(b_jets_input, newshape=(-1,Num_features))
b_jets_scaled = Scaler_jets.fit_transform(b_jets_scaled)
b_jets_input_scaled = np.reshape(b_jets_scaled, newshape= (Num_events,Num_features))
print(np.shape(b_jets_input_scaled))
# Out:
# (96659, 96, 15)
# (96659, 135)

# %%
# Builds the deep neural network
track_layers = [64 for x in range(2)]
jet_layers = [100 for x in range(3)]
b_jets_layers = [64 for x in range(2)]

track_layers = [np.shape(particles_input_scaled)[2]]+track_layers
print(track_layers)
print(np.shape(onehot)[1])
#Initializers the optimizer used for training the network
optimizer = tf.keras.optimizers.Nadam(LR)

#Build a DeepSets Projection Neural Network
DeepSetProjector = DeepSetsProjection(track_layers=track_layers, b_jet_layers= b_jets_layers, jet_layers=jet_layers, n_targets=np.shape(bhads_targets)[1], n_targets_classification= np.shape(onehot)[1], regularizer_strength= 1e-4, n_features=np.shape(b_jets_input_scaled)[1], Dropout_rate=0.1)
# Out:
# [15, 64, 64]
# 3

# %%
from DeepSetNeuralNetArchitecture import LogNormal_Loss_Function
from HffragDeepSetsProjection import Multivariate_Gaussian_Negative_Likelihood_Loss_Curve
from HffragDeepSetsProjectionMultivariate import weighted_categorical_crossentropy
DeepSetProjector.compile(
 optimizer = optimizer,
 loss = {"MultivariateLoss": Multivariate_Gaussian_Negative_Likelihood_Loss_Curve, "MassOutput":tf.keras.losses.categorical_crossentropy},
 metrics = [Mean_Squared_Error]   
)

# %%
#Summarises the DeepSetsProjector Set Neural Network Architecture
DeepSetProjector.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, None, 15)]   0           []
#
#  time_distributed_10 (TimeDistr  (None, None, 15)    240         ['input_7[0][0]']
#  ibuted)
#
#  time_distributed_residual_unit  (None, None, 15)    510         ['time_distributed_10[1][0]']
#  s_3 (TimeDistributedResidualUn
#  its)
#
#  time_distributed_13 (TimeDistr  (None, None, 64)    1024        ['time_distributed_residual_units
#  ibuted)                                                         _3[1][0]']
#
#  input_8 (InputLayer)           [(None, 135)]        0           []
#
#  time_distributed_residual_unit  (None, None, 64)    8448        ['time_distributed_13[1][0]']
#  s_4 (TimeDistributedResidualUn
#  its)
#
#  dense_30 (Dense)               (None, 64)           8704        ['input_8[0][0]']
#
#  time_distributed_16 (TimeDistr  (None, None, 64)    4160        ['time_distributed_residual_units
#  ibuted)                                                         _4[1][0]']
#
#  layer_normalization_9 (LayerNo  (None, 64)          128         ['dense_30[1][0]']
#  rmalization)
#
#  sum_1 (Sum)                    (None, 64)           0           ['time_distributed_16[1][0]']
#
#  dense_31 (Dense)               (None, 64)           4160        ['layer_normalization_9[1][0]']
#
#  concatenate_1 (Concatenate)    (None, 128)          0           ['sum_1[1][0]',
#                                                                   'dense_31[1][0]']
#
#  dense_32 (Dense)               (None, 100)          12900       ['concatenate_1[1][0]']
#
#  residual_units_2 (ResidualUnit  (None, 100)         20400       ['dense_32[1][0]']
#  s)
#
#  dense_35 (Dense)               (None, 100)          10100       ['residual_units_2[1][0]']
#
#  residual_units_3 (ResidualUnit  (None, 100)         20400       ['dense_35[1][0]']
#  s)
#
#  HuberLoss (Dense)              (None, 9)            909         ['residual_units_3[1][0]']
#
#  dense_40 (Dense)               (None, 64)           640         ['HuberLoss[1][0]']
#
#  dense_38 (Dense)               (None, 9)            909         ['residual_units_3[1][0]']
#
#  dense_39 (Dense)               (None, 36)           3636        ['residual_units_3[1][0]']
#
#  dense_41 (Dense)               (None, 64)           4160        ['dense_40[1][0]']
#
#  MultivariateLoss (Concatenate)  (None, 54)          0           ['HuberLoss[1][0]',
#                                                                   'dense_38[1][0]',
#                                                                   'dense_39[1][0]']
#
#  MassOutput (Dense)             (None, 3)            195         ['dense_41[1][0]']
#
# ==================================================================================================
# Total params: 101,623
# Trainable params: 101,623
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Introduce early_stopping to prevent overfitting
early_stopping = callbacks.EarlyStopping(
    min_delta=0.00001,  # The minimum amount of change to count as an improvement
    patience=50,  # The number of epochs to wait before stopping
    restore_best_weights=True,  # Keep the best weights
)
# Prevent spikes in the validation and training loss due to the gradient descent kicking the network out of a local minima
reduce_learn_on_plateau = callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.80, patience=15, min_lr=1e-9)

# Save the weights of the model to allow reuse in future.
path = "/home/physics/phujdj/DeepLearningParticlePhysics/CheckPointsDeepNet/ResidualDeepSetsWeights&BiasesLeptons.ckpt"
checkpoint_dir = os.path.dirname(path)
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=path,
                                                 save_weights_only=True, verbose=0, save_freq = 25*BATCHSIZE)
#Timer
#cb = TimingCallback()

#Weight&Biases Callback:
#Wanda = WandbCallback(save_graph = True,save_weights_only = True, log_weights = True, log_gradients = True, log_evaluation = True, training_data = (X_train,y_train), validation_data = (X_valid,y_valid), log_batch_frequency = 5)

# Learning Scheduler:
exponential_decay_fn = DSNNA.expontial_decay(lr0 = LR,s = 100)
learning_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# %%
history  = DeepSetProjector.fit(
    (particles_input_scaled,b_jets_input_scaled), y = {"MultivariateLoss":bhads_targets, "MassOutput":onehot},
    validation_split = 0.3,
    epochs = EPOCHS,
    batch_size = BATCHSIZE,
    callbacks = [early_stopping, cp_callback, reduce_learn_on_plateau],
    )
# Out:
# Epoch 1/1000
# 1058/1058 [==============================] - 30s 21ms/step - loss: 11.0296 - MultivariateLoss_loss: -4.8246 - MassOutput_loss: 1.0147 - MultivariateLoss_Mean_Squared_Error: 0.4252 - MassOutput_Mean_Squared_Error: 0.2060 - val_loss: 4.8801 - val_MultivariateLoss_loss: -9.1177 - val_MassOutput_loss: 1.0139 - val_MultivariateLoss_Mean_Squared_Error: 0.2968 - val_MassOutput_Mean_Squared_Error: 0.2057 - lr: 3.0000e-04
# Epoch 2/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: 2.1847 - MultivariateLoss_loss: -10.7480 - MassOutput_loss: 1.0098 - MultivariateLoss_Mean_Squared_Error: 0.1500 - MassOutput_Mean_Squared_Error: 0.2051 - val_loss: -0.2789 - val_MultivariateLoss_loss: -12.3435 - val_MassOutput_loss: 1.0152 - val_MultivariateLoss_Mean_Squared_Error: 0.0426 - val_MassOutput_Mean_Squared_Error: 0.2059 - lr: 3.0000e-04
# Epoch 3/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -1.8751 - MultivariateLoss_loss: -13.3080 - MassOutput_loss: 1.0098 - MultivariateLoss_Mean_Squared_Error: 0.0352 - MassOutput_Mean_Squared_Error: 0.2052 - val_loss: -2.4733 - val_MultivariateLoss_loss: -13.3652 - val_MassOutput_loss: 1.0126 - val_MultivariateLoss_Mean_Squared_Error: 0.0295 - val_MassOutput_Mean_Squared_Error: 0.2055 - lr: 3.0000e-04
# Epoch 4/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -3.8137 - MultivariateLoss_loss: -14.2738 - MassOutput_loss: 1.0092 - MultivariateLoss_Mean_Squared_Error: 0.0301 - MassOutput_Mean_Squared_Error: 0.2050 - val_loss: -5.0212 - val_MultivariateLoss_loss: -15.0933 - val_MassOutput_loss: 1.0112 - val_MultivariateLoss_Mean_Squared_Error: 0.0268 - val_MassOutput_Mean_Squared_Error: 0.2053 - lr: 3.0000e-04
# Epoch 5/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -4.9814 - MultivariateLoss_loss: -14.7230 - MassOutput_loss: 1.0088 - MultivariateLoss_Mean_Squared_Error: 0.0283 - MassOutput_Mean_Squared_Error: 0.2049 - val_loss: -5.3925 - val_MultivariateLoss_loss: -14.8341 - val_MassOutput_loss: 1.0121 - val_MultivariateLoss_Mean_Squared_Error: 0.0262 - val_MassOutput_Mean_Squared_Error: 0.2055 - lr: 3.0000e-04
# Epoch 6/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -5.9621 - MultivariateLoss_loss: -15.1322 - MassOutput_loss: 1.0085 - MultivariateLoss_Mean_Squared_Error: 0.0276 - MassOutput_Mean_Squared_Error: 0.2049 - val_loss: -5.9493 - val_MultivariateLoss_loss: -14.8687 - val_MassOutput_loss: 1.0112 - val_MultivariateLoss_Mean_Squared_Error: 0.0253 - val_MassOutput_Mean_Squared_Error: 0.2053 - lr: 3.0000e-04
# Epoch 7/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -6.6219 - MultivariateLoss_loss: -15.3117 - MassOutput_loss: 1.0085 - MultivariateLoss_Mean_Squared_Error: 0.0271 - MassOutput_Mean_Squared_Error: 0.2049 - val_loss: -5.4827 - val_MultivariateLoss_loss: -13.9581 - val_MassOutput_loss: 1.0120 - val_MultivariateLoss_Mean_Squared_Error: 0.0256 - val_MassOutput_Mean_Squared_Error: 0.2055 - lr: 3.0000e-04
# Epoch 8/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -7.1869 - MultivariateLoss_loss: -15.4601 - MassOutput_loss: 1.0084 - MultivariateLoss_Mean_Squared_Error: 0.0267 - MassOutput_Mean_Squared_Error: 0.2048 - val_loss: -7.4712 - val_MultivariateLoss_loss: -15.5580 - val_MassOutput_loss: 1.0122 - val_MultivariateLoss_Mean_Squared_Error: 0.0247 - val_MassOutput_Mean_Squared_Error: 0.2056 - lr: 3.0000e-04
# Epoch 9/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -7.7547 - MultivariateLoss_loss: -15.6611 - MassOutput_loss: 1.0081 - MultivariateLoss_Mean_Squared_Error: 0.0265 - MassOutput_Mean_Squared_Error: 0.2048 - val_loss: -7.9348 - val_MultivariateLoss_loss: -15.6750 - val_MassOutput_loss: 1.0125 - val_MultivariateLoss_Mean_Squared_Error: 0.0244 - val_MassOutput_Mean_Squared_Error: 0.2057 - lr: 3.0000e-04
# Epoch 10/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -8.1762 - MultivariateLoss_loss: -15.7546 - MassOutput_loss: 1.0082 - MultivariateLoss_Mean_Squared_Error: 0.0262 - MassOutput_Mean_Squared_Error: 0.2048 - val_loss: -8.3733 - val_MultivariateLoss_loss: -15.8026 - val_MassOutput_loss: 1.0118 - val_MultivariateLoss_Mean_Squared_Error: 0.0241 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 11/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -8.5674 - MultivariateLoss_loss: -15.8509 - MassOutput_loss: 1.0081 - MultivariateLoss_Mean_Squared_Error: 0.0261 - MassOutput_Mean_Squared_Error: 0.2048 - val_loss: -7.5076 - val_MultivariateLoss_loss: -14.6564 - val_MassOutput_loss: 1.0116 - val_MultivariateLoss_Mean_Squared_Error: 0.0244 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 12/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -8.9240 - MultivariateLoss_loss: -15.9404 - MassOutput_loss: 1.0079 - MultivariateLoss_Mean_Squared_Error: 0.0259 - MassOutput_Mean_Squared_Error: 0.2047 - val_loss: -8.7974 - val_MultivariateLoss_loss: -15.6933 - val_MassOutput_loss: 1.0122 - val_MultivariateLoss_Mean_Squared_Error: 0.0240 - val_MassOutput_Mean_Squared_Error: 0.2056 - lr: 3.0000e-04
# Epoch 13/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -9.1991 - MultivariateLoss_loss: -15.9733 - MassOutput_loss: 1.0080 - MultivariateLoss_Mean_Squared_Error: 0.0258 - MassOutput_Mean_Squared_Error: 0.2048 - val_loss: -8.3410 - val_MultivariateLoss_loss: -15.0044 - val_MassOutput_loss: 1.0114 - val_MultivariateLoss_Mean_Squared_Error: 0.0239 - val_MassOutput_Mean_Squared_Error: 0.2053 - lr: 3.0000e-04
# Epoch 14/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -9.6086 - MultivariateLoss_loss: -16.1603 - MassOutput_loss: 1.0081 - MultivariateLoss_Mean_Squared_Error: 0.0256 - MassOutput_Mean_Squared_Error: 0.2048 - val_loss: -7.7206 - val_MultivariateLoss_loss: -14.1697 - val_MassOutput_loss: 1.0121 - val_MultivariateLoss_Mean_Squared_Error: 0.0243 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 15/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -9.8134 - MultivariateLoss_loss: -16.1571 - MassOutput_loss: 1.0077 - MultivariateLoss_Mean_Squared_Error: 0.0256 - MassOutput_Mean_Squared_Error: 0.2047 - val_loss: -9.4907 - val_MultivariateLoss_loss: -15.7409 - val_MassOutput_loss: 1.0125 - val_MultivariateLoss_Mean_Squared_Error: 0.0237 - val_MassOutput_Mean_Squared_Error: 0.2056 - lr: 3.0000e-04
# Epoch 16/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -10.0800 - MultivariateLoss_loss: -16.2332 - MassOutput_loss: 1.0077 - MultivariateLoss_Mean_Squared_Error: 0.0255 - MassOutput_Mean_Squared_Error: 0.2047 - val_loss: -7.8904 - val_MultivariateLoss_loss: -13.9563 - val_MassOutput_loss: 1.0115 - val_MultivariateLoss_Mean_Squared_Error: 0.0240 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 17/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -10.2723 - MultivariateLoss_loss: -16.2494 - MassOutput_loss: 1.0078 - MultivariateLoss_Mean_Squared_Error: 0.0254 - MassOutput_Mean_Squared_Error: 0.2047 - val_loss: -9.6903 - val_MultivariateLoss_loss: -15.5873 - val_MassOutput_loss: 1.0120 - val_MultivariateLoss_Mean_Squared_Error: 0.0234 - val_MassOutput_Mean_Squared_Error: 0.2055 - lr: 3.0000e-04
# Epoch 18/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -10.5146 - MultivariateLoss_loss: -16.3271 - MassOutput_loss: 1.0076 - MultivariateLoss_Mean_Squared_Error: 0.0252 - MassOutput_Mean_Squared_Error: 0.2047 - val_loss: -10.4237 - val_MultivariateLoss_loss: -16.1625 - val_MassOutput_loss: 1.0118 - val_MultivariateLoss_Mean_Squared_Error: 0.0233 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 19/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -10.7285 - MultivariateLoss_loss: -16.3883 - MassOutput_loss: 1.0075 - MultivariateLoss_Mean_Squared_Error: 0.0252 - MassOutput_Mean_Squared_Error: 0.2047 - val_loss: -10.2733 - val_MultivariateLoss_loss: -15.8639 - val_MassOutput_loss: 1.0113 - val_MultivariateLoss_Mean_Squared_Error: 0.0234 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 20/1000
# 1058/1058 [==============================] - 22s 20ms/step - loss: -10.9274 - MultivariateLoss_loss: -16.4441 - MassOutput_loss: 1.0075 - MultivariateLoss_Mean_Squared_Error: 0.0251 - MassOutput_Mean_Squared_Error: 0.2047 - val_loss: -9.3704 - val_MultivariateLoss_loss: -14.8226 - val_MassOutput_loss: 1.0115 - val_MultivariateLoss_Mean_Squared_Error: 0.0235 - val_MassOutput_Mean_Squared_Error: 0.2053 - lr: 3.0000e-04
# Epoch 21/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -11.1100 - MultivariateLoss_loss: -16.4941 - MassOutput_loss: 1.0075 - MultivariateLoss_Mean_Squared_Error: 0.0251 - MassOutput_Mean_Squared_Error: 0.2047 - val_loss: -10.9167 - val_MultivariateLoss_loss: -16.2405 - val_MassOutput_loss: 1.0115 - val_MultivariateLoss_Mean_Squared_Error: 0.0235 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 22/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -11.2537 - MultivariateLoss_loss: -16.5129 - MassOutput_loss: 1.0074 - MultivariateLoss_Mean_Squared_Error: 0.0251 - MassOutput_Mean_Squared_Error: 0.2046 - val_loss: -11.1016 - val_MultivariateLoss_loss: -16.3046 - val_MassOutput_loss: 1.0116 - val_MultivariateLoss_Mean_Squared_Error: 0.0232 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 23/1000
# 1058/1058 [==============================] - 22s 20ms/step - loss: -11.3764 - MultivariateLoss_loss: -16.5184 - MassOutput_loss: 1.0075 - MultivariateLoss_Mean_Squared_Error: 0.0251 - MassOutput_Mean_Squared_Error: 0.2047 - val_loss: -10.6395 - val_MultivariateLoss_loss: -15.7296 - val_MassOutput_loss: 1.0112 - val_MultivariateLoss_Mean_Squared_Error: 0.0235 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 24/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -11.6017 - MultivariateLoss_loss: -16.6339 - MassOutput_loss: 1.0074 - MultivariateLoss_Mean_Squared_Error: 0.0250 - MassOutput_Mean_Squared_Error: 0.2046 - val_loss: -9.4499 - val_MultivariateLoss_loss: -14.4318 - val_MassOutput_loss: 1.0112 - val_MultivariateLoss_Mean_Squared_Error: 0.0234 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 25/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -11.6703 - MultivariateLoss_loss: -16.5966 - MassOutput_loss: 1.0073 - MultivariateLoss_Mean_Squared_Error: 0.0249 - MassOutput_Mean_Squared_Error: 0.2046 - val_loss: -6.2323 - val_MultivariateLoss_loss: -11.1119 - val_MassOutput_loss: 1.0113 - val_MultivariateLoss_Mean_Squared_Error: 0.0240 - val_MassOutput_Mean_Squared_Error: 0.2053 - lr: 3.0000e-04
# Epoch 26/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -11.7981 - MultivariateLoss_loss: -16.6262 - MassOutput_loss: 1.0073 - MultivariateLoss_Mean_Squared_Error: 0.0250 - MassOutput_Mean_Squared_Error: 0.2046 - val_loss: -11.5321 - val_MultivariateLoss_loss: -16.3159 - val_MassOutput_loss: 1.0109 - val_MultivariateLoss_Mean_Squared_Error: 0.0229 - val_MassOutput_Mean_Squared_Error: 0.2053 - lr: 3.0000e-04
# Epoch 27/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -11.9738 - MultivariateLoss_loss: -16.7081 - MassOutput_loss: 1.0071 - MultivariateLoss_Mean_Squared_Error: 0.0249 - MassOutput_Mean_Squared_Error: 0.2046 - val_loss: -7.8384 - val_MultivariateLoss_loss: -12.5302 - val_MassOutput_loss: 1.0107 - val_MultivariateLoss_Mean_Squared_Error: 0.0239 - val_MassOutput_Mean_Squared_Error: 0.2052 - lr: 3.0000e-04
# Epoch 28/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -11.9475 - MultivariateLoss_loss: -16.5921 - MassOutput_loss: 1.0074 - MultivariateLoss_Mean_Squared_Error: 0.0248 - MassOutput_Mean_Squared_Error: 0.2046 - val_loss: -11.7299 - val_MultivariateLoss_loss: -16.3361 - val_MassOutput_loss: 1.0114 - val_MultivariateLoss_Mean_Squared_Error: 0.0231 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 29/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -12.1552 - MultivariateLoss_loss: -16.7139 - MassOutput_loss: 1.0072 - MultivariateLoss_Mean_Squared_Error: 0.0248 - MassOutput_Mean_Squared_Error: 0.2046 - val_loss: -11.2742 - val_MultivariateLoss_loss: -15.7970 - val_MassOutput_loss: 1.0121 - val_MultivariateLoss_Mean_Squared_Error: 0.0229 - val_MassOutput_Mean_Squared_Error: 0.2056 - lr: 3.0000e-04
# Epoch 30/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -12.3394 - MultivariateLoss_loss: -16.8161 - MassOutput_loss: 1.0073 - MultivariateLoss_Mean_Squared_Error: 0.0248 - MassOutput_Mean_Squared_Error: 0.2046 - val_loss: -11.5539 - val_MultivariateLoss_loss: -15.9946 - val_MassOutput_loss: 1.0115 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2053 - lr: 3.0000e-04
# Epoch 31/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -12.3989 - MultivariateLoss_loss: -16.7975 - MassOutput_loss: 1.0072 - MultivariateLoss_Mean_Squared_Error: 0.0248 - MassOutput_Mean_Squared_Error: 0.2046 - val_loss: -10.6796 - val_MultivariateLoss_loss: -15.0435 - val_MassOutput_loss: 1.0112 - val_MultivariateLoss_Mean_Squared_Error: 0.0233 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 32/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -12.4307 - MultivariateLoss_loss: -16.7542 - MassOutput_loss: 1.0072 - MultivariateLoss_Mean_Squared_Error: 0.0248 - MassOutput_Mean_Squared_Error: 0.2046 - val_loss: -11.7716 - val_MultivariateLoss_loss: -16.0653 - val_MassOutput_loss: 1.0112 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2053 - lr: 3.0000e-04
# Epoch 33/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -12.6247 - MultivariateLoss_loss: -16.8771 - MassOutput_loss: 1.0072 - MultivariateLoss_Mean_Squared_Error: 0.0248 - MassOutput_Mean_Squared_Error: 0.2046 - val_loss: -12.4458 - val_MultivariateLoss_loss: -16.6666 - val_MassOutput_loss: 1.0111 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2053 - lr: 3.0000e-04
# Epoch 34/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -12.7211 - MultivariateLoss_loss: -16.9032 - MassOutput_loss: 1.0071 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2046 - val_loss: -12.4257 - val_MultivariateLoss_loss: -16.5773 - val_MassOutput_loss: 1.0118 - val_MultivariateLoss_Mean_Squared_Error: 0.0228 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 35/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -12.7912 - MultivariateLoss_loss: -16.9047 - MassOutput_loss: 1.0070 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2046 - val_loss: -10.8569 - val_MultivariateLoss_loss: -14.9421 - val_MassOutput_loss: 1.0109 - val_MultivariateLoss_Mean_Squared_Error: 0.0236 - val_MassOutput_Mean_Squared_Error: 0.2053 - lr: 3.0000e-04
# Epoch 36/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -12.9018 - MultivariateLoss_loss: -16.9511 - MassOutput_loss: 1.0070 - MultivariateLoss_Mean_Squared_Error: 0.0248 - MassOutput_Mean_Squared_Error: 0.2046 - val_loss: -12.1686 - val_MultivariateLoss_loss: -16.1911 - val_MassOutput_loss: 1.0115 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 37/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -13.0187 - MultivariateLoss_loss: -17.0067 - MassOutput_loss: 1.0070 - MultivariateLoss_Mean_Squared_Error: 0.0248 - MassOutput_Mean_Squared_Error: 0.2046 - val_loss: -12.6853 - val_MultivariateLoss_loss: -16.6463 - val_MassOutput_loss: 1.0112 - val_MultivariateLoss_Mean_Squared_Error: 0.0229 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 38/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -13.0802 - MultivariateLoss_loss: -17.0081 - MassOutput_loss: 1.0069 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -12.8162 - val_MultivariateLoss_loss: -16.7192 - val_MassOutput_loss: 1.0113 - val_MultivariateLoss_Mean_Squared_Error: 0.0228 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 39/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -13.1240 - MultivariateLoss_loss: -16.9944 - MassOutput_loss: 1.0069 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -12.5062 - val_MultivariateLoss_loss: -16.3531 - val_MassOutput_loss: 1.0118 - val_MultivariateLoss_Mean_Squared_Error: 0.0229 - val_MassOutput_Mean_Squared_Error: 0.2055 - lr: 3.0000e-04
# Epoch 40/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -13.2005 - MultivariateLoss_loss: -17.0150 - MassOutput_loss: 1.0069 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -12.9343 - val_MultivariateLoss_loss: -16.7259 - val_MassOutput_loss: 1.0113 - val_MultivariateLoss_Mean_Squared_Error: 0.0228 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 41/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -13.3209 - MultivariateLoss_loss: -17.0818 - MassOutput_loss: 1.0069 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -11.4295 - val_MultivariateLoss_loss: -15.1687 - val_MassOutput_loss: 1.0111 - val_MultivariateLoss_Mean_Squared_Error: 0.0229 - val_MassOutput_Mean_Squared_Error: 0.2053 - lr: 3.0000e-04
# Epoch 42/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -13.3980 - MultivariateLoss_loss: -17.1067 - MassOutput_loss: 1.0069 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -11.8396 - val_MultivariateLoss_loss: -15.5266 - val_MassOutput_loss: 1.0114 - val_MultivariateLoss_Mean_Squared_Error: 0.0229 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 43/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -13.3724 - MultivariateLoss_loss: -17.0303 - MassOutput_loss: 1.0069 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -12.4591 - val_MultivariateLoss_loss: -16.1011 - val_MassOutput_loss: 1.0117 - val_MultivariateLoss_Mean_Squared_Error: 0.0234 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 44/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -13.4467 - MultivariateLoss_loss: -17.0581 - MassOutput_loss: 1.0068 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -12.7516 - val_MultivariateLoss_loss: -16.3419 - val_MassOutput_loss: 1.0111 - val_MultivariateLoss_Mean_Squared_Error: 0.0226 - val_MassOutput_Mean_Squared_Error: 0.2053 - lr: 3.0000e-04
# Epoch 45/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -13.5635 - MultivariateLoss_loss: -17.1262 - MassOutput_loss: 1.0068 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -13.0413 - val_MultivariateLoss_loss: -16.5845 - val_MassOutput_loss: 1.0114 - val_MultivariateLoss_Mean_Squared_Error: 0.0228 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 46/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -13.6024 - MultivariateLoss_loss: -17.1189 - MassOutput_loss: 1.0069 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -11.3037 - val_MultivariateLoss_loss: -14.8026 - val_MassOutput_loss: 1.0111 - val_MultivariateLoss_Mean_Squared_Error: 0.0229 - val_MassOutput_Mean_Squared_Error: 0.2053 - lr: 3.0000e-04
# Epoch 47/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -13.6633 - MultivariateLoss_loss: -17.1367 - MassOutput_loss: 1.0068 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -13.1497 - val_MultivariateLoss_loss: -16.6049 - val_MassOutput_loss: 1.0111 - val_MultivariateLoss_Mean_Squared_Error: 0.0226 - val_MassOutput_Mean_Squared_Error: 0.2053 - lr: 3.0000e-04
# Epoch 48/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -13.7837 - MultivariateLoss_loss: -17.2132 - MassOutput_loss: 1.0067 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -11.2861 - val_MultivariateLoss_loss: -14.6983 - val_MassOutput_loss: 1.0117 - val_MultivariateLoss_Mean_Squared_Error: 0.0229 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 49/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -13.7736 - MultivariateLoss_loss: -17.1608 - MassOutput_loss: 1.0068 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -11.2631 - val_MultivariateLoss_loss: -14.6332 - val_MassOutput_loss: 1.0115 - val_MultivariateLoss_Mean_Squared_Error: 0.0229 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 50/1000
# 1058/1058 [==============================] - 20s 19ms/step - loss: -13.8634 - MultivariateLoss_loss: -17.2091 - MassOutput_loss: 1.0067 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -13.0745 - val_MultivariateLoss_loss: -16.4044 - val_MassOutput_loss: 1.0112 - val_MultivariateLoss_Mean_Squared_Error: 0.0227 - val_MassOutput_Mean_Squared_Error: 0.2053 - lr: 3.0000e-04
# Epoch 51/1000
# 1058/1058 [==============================] - 21s 19ms/step - loss: -13.8642 - MultivariateLoss_loss: -17.1714 - MassOutput_loss: 1.0068 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -13.8458 - val_MultivariateLoss_loss: -17.1375 - val_MassOutput_loss: 1.0112 - val_MultivariateLoss_Mean_Squared_Error: 0.0224 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 52/1000
# 1058/1058 [==============================] - 21s 19ms/step - loss: -14.0236 - MultivariateLoss_loss: -17.2921 - MassOutput_loss: 1.0067 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -12.5562 - val_MultivariateLoss_loss: -15.8093 - val_MassOutput_loss: 1.0112 - val_MultivariateLoss_Mean_Squared_Error: 0.0228 - val_MassOutput_Mean_Squared_Error: 0.2053 - lr: 3.0000e-04
# Epoch 53/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -13.9278 - MultivariateLoss_loss: -17.1588 - MassOutput_loss: 1.0066 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -13.0699 - val_MultivariateLoss_loss: -16.2889 - val_MassOutput_loss: 1.0113 - val_MultivariateLoss_Mean_Squared_Error: 0.0226 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 54/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -14.0662 - MultivariateLoss_loss: -17.2624 - MassOutput_loss: 1.0068 - MultivariateLoss_Mean_Squared_Error: 0.0245 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -13.4894 - val_MultivariateLoss_loss: -16.6768 - val_MassOutput_loss: 1.0110 - val_MultivariateLoss_Mean_Squared_Error: 0.0227 - val_MassOutput_Mean_Squared_Error: 0.2053 - lr: 3.0000e-04
# Epoch 55/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -14.0937 - MultivariateLoss_loss: -17.2563 - MassOutput_loss: 1.0067 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -12.9672 - val_MultivariateLoss_loss: -16.1162 - val_MassOutput_loss: 1.0112 - val_MultivariateLoss_Mean_Squared_Error: 0.0227 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 56/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -14.1794 - MultivariateLoss_loss: -17.3055 - MassOutput_loss: 1.0066 - MultivariateLoss_Mean_Squared_Error: 0.0245 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -13.8239 - val_MultivariateLoss_loss: -16.9377 - val_MassOutput_loss: 1.0113 - val_MultivariateLoss_Mean_Squared_Error: 0.0226 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 57/1000
# 1058/1058 [==============================] - 20s 19ms/step - loss: -14.1796 - MultivariateLoss_loss: -17.2718 - MassOutput_loss: 1.0066 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -13.6466 - val_MultivariateLoss_loss: -16.7266 - val_MassOutput_loss: 1.0113 - val_MultivariateLoss_Mean_Squared_Error: 0.0224 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 58/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -14.2554 - MultivariateLoss_loss: -17.3144 - MassOutput_loss: 1.0065 - MultivariateLoss_Mean_Squared_Error: 0.0245 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -14.0541 - val_MultivariateLoss_loss: -17.1016 - val_MassOutput_loss: 1.0119 - val_MultivariateLoss_Mean_Squared_Error: 0.0227 - val_MassOutput_Mean_Squared_Error: 0.2055 - lr: 3.0000e-04
# Epoch 59/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -14.3386 - MultivariateLoss_loss: -17.3650 - MassOutput_loss: 1.0066 - MultivariateLoss_Mean_Squared_Error: 0.0245 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -8.1838 - val_MultivariateLoss_loss: -11.1996 - val_MassOutput_loss: 1.0113 - val_MultivariateLoss_Mean_Squared_Error: 0.0229 - val_MassOutput_Mean_Squared_Error: 0.2053 - lr: 3.0000e-04
# Epoch 60/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -14.3674 - MultivariateLoss_loss: -17.3620 - MassOutput_loss: 1.0064 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -12.8637 - val_MultivariateLoss_loss: -15.8469 - val_MassOutput_loss: 1.0115 - val_MultivariateLoss_Mean_Squared_Error: 0.0227 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 61/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -14.3659 - MultivariateLoss_loss: -17.3298 - MassOutput_loss: 1.0066 - MultivariateLoss_Mean_Squared_Error: 0.0245 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -14.0793 - val_MultivariateLoss_loss: -17.0331 - val_MassOutput_loss: 1.0110 - val_MultivariateLoss_Mean_Squared_Error: 0.0227 - val_MassOutput_Mean_Squared_Error: 0.2053 - lr: 3.0000e-04
# Epoch 62/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -14.4456 - MultivariateLoss_loss: -17.3795 - MassOutput_loss: 1.0066 - MultivariateLoss_Mean_Squared_Error: 0.0245 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -11.3010 - val_MultivariateLoss_loss: -14.2248 - val_MassOutput_loss: 1.0113 - val_MultivariateLoss_Mean_Squared_Error: 0.0226 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 63/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -14.4662 - MultivariateLoss_loss: -17.3705 - MassOutput_loss: 1.0065 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -13.6821 - val_MultivariateLoss_loss: -16.5756 - val_MassOutput_loss: 1.0109 - val_MultivariateLoss_Mean_Squared_Error: 0.0227 - val_MassOutput_Mean_Squared_Error: 0.2053 - lr: 3.0000e-04
# Epoch 64/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -14.5358 - MultivariateLoss_loss: -17.4107 - MassOutput_loss: 1.0066 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -13.1531 - val_MultivariateLoss_loss: -16.0182 - val_MassOutput_loss: 1.0113 - val_MultivariateLoss_Mean_Squared_Error: 0.0229 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 65/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -14.5164 - MultivariateLoss_loss: -17.3627 - MassOutput_loss: 1.0065 - MultivariateLoss_Mean_Squared_Error: 0.0245 - MassOutput_Mean_Squared_Error: 0.2045 - val_loss: -12.1426 - val_MultivariateLoss_loss: -14.9843 - val_MassOutput_loss: 1.0111 - val_MultivariateLoss_Mean_Squared_Error: 0.0226 - val_MassOutput_Mean_Squared_Error: 0.2053 - lr: 3.0000e-04
# Epoch 66/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -14.5760 - MultivariateLoss_loss: -17.4011 - MassOutput_loss: 1.0064 - MultivariateLoss_Mean_Squared_Error: 0.0245 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -13.5046 - val_MultivariateLoss_loss: -16.3192 - val_MassOutput_loss: 1.0115 - val_MultivariateLoss_Mean_Squared_Error: 0.0228 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 67/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -14.6141 - MultivariateLoss_loss: -17.4091 - MassOutput_loss: 1.0065 - MultivariateLoss_Mean_Squared_Error: 0.0245 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -13.5358 - val_MultivariateLoss_loss: -16.3218 - val_MassOutput_loss: 1.0112 - val_MultivariateLoss_Mean_Squared_Error: 0.0227 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 68/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -14.6888 - MultivariateLoss_loss: -17.4568 - MassOutput_loss: 1.0065 - MultivariateLoss_Mean_Squared_Error: 0.0245 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -12.0893 - val_MultivariateLoss_loss: -14.8481 - val_MassOutput_loss: 1.0112 - val_MultivariateLoss_Mean_Squared_Error: 0.0229 - val_MassOutput_Mean_Squared_Error: 0.2053 - lr: 3.0000e-04
# Epoch 69/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -14.7043 - MultivariateLoss_loss: -17.4467 - MassOutput_loss: 1.0065 - MultivariateLoss_Mean_Squared_Error: 0.0245 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -12.9904 - val_MultivariateLoss_loss: -15.7242 - val_MassOutput_loss: 1.0111 - val_MultivariateLoss_Mean_Squared_Error: 0.0226 - val_MassOutput_Mean_Squared_Error: 0.2053 - lr: 3.0000e-04
# Epoch 70/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -14.7657 - MultivariateLoss_loss: -17.4826 - MassOutput_loss: 1.0064 - MultivariateLoss_Mean_Squared_Error: 0.0245 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -14.4937 - val_MultivariateLoss_loss: -17.2033 - val_MassOutput_loss: 1.0115 - val_MultivariateLoss_Mean_Squared_Error: 0.0226 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 71/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -14.7522 - MultivariateLoss_loss: -17.4457 - MassOutput_loss: 1.0063 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -13.7007 - val_MultivariateLoss_loss: -16.3876 - val_MassOutput_loss: 1.0115 - val_MultivariateLoss_Mean_Squared_Error: 0.0228 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 72/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -14.8228 - MultivariateLoss_loss: -17.4930 - MassOutput_loss: 1.0064 - MultivariateLoss_Mean_Squared_Error: 0.0245 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -13.0351 - val_MultivariateLoss_loss: -15.6977 - val_MassOutput_loss: 1.0112 - val_MultivariateLoss_Mean_Squared_Error: 0.0226 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 73/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -14.8614 - MultivariateLoss_loss: -17.5080 - MassOutput_loss: 1.0064 - MultivariateLoss_Mean_Squared_Error: 0.0245 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -14.6747 - val_MultivariateLoss_loss: -17.3154 - val_MassOutput_loss: 1.0117 - val_MultivariateLoss_Mean_Squared_Error: 0.0225 - val_MassOutput_Mean_Squared_Error: 0.2055 - lr: 3.0000e-04
# Epoch 74/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -14.9113 - MultivariateLoss_loss: -17.5360 - MassOutput_loss: 1.0064 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -14.1923 - val_MultivariateLoss_loss: -16.8111 - val_MassOutput_loss: 1.0115 - val_MultivariateLoss_Mean_Squared_Error: 0.0227 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 75/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -14.9035 - MultivariateLoss_loss: -17.5068 - MassOutput_loss: 1.0063 - MultivariateLoss_Mean_Squared_Error: 0.0245 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -13.9903 - val_MultivariateLoss_loss: -16.5880 - val_MassOutput_loss: 1.0116 - val_MultivariateLoss_Mean_Squared_Error: 0.0227 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 76/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -14.9293 - MultivariateLoss_loss: -17.5138 - MassOutput_loss: 1.0063 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -13.7608 - val_MultivariateLoss_loss: -16.3389 - val_MassOutput_loss: 1.0113 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 77/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -14.9742 - MultivariateLoss_loss: -17.5372 - MassOutput_loss: 1.0063 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -14.3205 - val_MultivariateLoss_loss: -16.8782 - val_MassOutput_loss: 1.0112 - val_MultivariateLoss_Mean_Squared_Error: 0.0227 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 78/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -14.9791 - MultivariateLoss_loss: -17.5229 - MassOutput_loss: 1.0063 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -13.7014 - val_MultivariateLoss_loss: -16.2402 - val_MassOutput_loss: 1.0111 - val_MultivariateLoss_Mean_Squared_Error: 0.0227 - val_MassOutput_Mean_Squared_Error: 0.2053 - lr: 3.0000e-04
# Epoch 79/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.0458 - MultivariateLoss_loss: -17.5707 - MassOutput_loss: 1.0064 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -14.4767 - val_MultivariateLoss_loss: -16.9973 - val_MassOutput_loss: 1.0115 - val_MultivariateLoss_Mean_Squared_Error: 0.0226 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 80/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.0678 - MultivariateLoss_loss: -17.5742 - MassOutput_loss: 1.0063 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -14.6290 - val_MultivariateLoss_loss: -17.1311 - val_MassOutput_loss: 1.0114 - val_MultivariateLoss_Mean_Squared_Error: 0.0225 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 81/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.1015 - MultivariateLoss_loss: -17.5893 - MassOutput_loss: 1.0063 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -14.5645 - val_MultivariateLoss_loss: -17.0482 - val_MassOutput_loss: 1.0114 - val_MultivariateLoss_Mean_Squared_Error: 0.0227 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 82/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.1070 - MultivariateLoss_loss: -17.5771 - MassOutput_loss: 1.0062 - MultivariateLoss_Mean_Squared_Error: 0.0245 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -14.2813 - val_MultivariateLoss_loss: -16.7478 - val_MassOutput_loss: 1.0116 - val_MultivariateLoss_Mean_Squared_Error: 0.0226 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 83/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.1437 - MultivariateLoss_loss: -17.5962 - MassOutput_loss: 1.0063 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -14.7692 - val_MultivariateLoss_loss: -17.2185 - val_MassOutput_loss: 1.0114 - val_MultivariateLoss_Mean_Squared_Error: 0.0225 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 84/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.1953 - MultivariateLoss_loss: -17.6316 - MassOutput_loss: 1.0063 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -13.5025 - val_MultivariateLoss_loss: -15.9360 - val_MassOutput_loss: 1.0111 - val_MultivariateLoss_Mean_Squared_Error: 0.0227 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 85/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.1919 - MultivariateLoss_loss: -17.6117 - MassOutput_loss: 1.0063 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -14.3874 - val_MultivariateLoss_loss: -16.8036 - val_MassOutput_loss: 1.0112 - val_MultivariateLoss_Mean_Squared_Error: 0.0227 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 86/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.2317 - MultivariateLoss_loss: -17.6347 - MassOutput_loss: 1.0062 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -14.0931 - val_MultivariateLoss_loss: -16.4935 - val_MassOutput_loss: 1.0118 - val_MultivariateLoss_Mean_Squared_Error: 0.0228 - val_MassOutput_Mean_Squared_Error: 0.2055 - lr: 3.0000e-04
# Epoch 87/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.2740 - MultivariateLoss_loss: -17.6605 - MassOutput_loss: 1.0062 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -14.5642 - val_MultivariateLoss_loss: -16.9472 - val_MassOutput_loss: 1.0112 - val_MultivariateLoss_Mean_Squared_Error: 0.0229 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 88/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.2722 - MultivariateLoss_loss: -17.6433 - MassOutput_loss: 1.0062 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -14.4570 - val_MultivariateLoss_loss: -16.8258 - val_MassOutput_loss: 1.0116 - val_MultivariateLoss_Mean_Squared_Error: 0.0228 - val_MassOutput_Mean_Squared_Error: 0.2055 - lr: 3.0000e-04
# Epoch 89/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.2698 - MultivariateLoss_loss: -17.6256 - MassOutput_loss: 1.0062 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -11.7410 - val_MultivariateLoss_loss: -14.0959 - val_MassOutput_loss: 1.0115 - val_MultivariateLoss_Mean_Squared_Error: 0.0227 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 90/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.3202 - MultivariateLoss_loss: -17.6619 - MassOutput_loss: 1.0062 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -14.8552 - val_MultivariateLoss_loss: -17.1942 - val_MassOutput_loss: 1.0114 - val_MultivariateLoss_Mean_Squared_Error: 0.0227 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 91/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.3468 - MultivariateLoss_loss: -17.6736 - MassOutput_loss: 1.0062 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -14.7556 - val_MultivariateLoss_loss: -17.0803 - val_MassOutput_loss: 1.0114 - val_MultivariateLoss_Mean_Squared_Error: 0.0228 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 92/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.3491 - MultivariateLoss_loss: -17.6619 - MassOutput_loss: 1.0062 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -14.9927 - val_MultivariateLoss_loss: -17.3036 - val_MassOutput_loss: 1.0113 - val_MultivariateLoss_Mean_Squared_Error: 0.0227 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 93/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.4073 - MultivariateLoss_loss: -17.7068 - MassOutput_loss: 1.0062 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -14.3824 - val_MultivariateLoss_loss: -16.6803 - val_MassOutput_loss: 1.0120 - val_MultivariateLoss_Mean_Squared_Error: 0.0228 - val_MassOutput_Mean_Squared_Error: 0.2055 - lr: 3.0000e-04
# Epoch 94/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.4187 - MultivariateLoss_loss: -17.7037 - MassOutput_loss: 1.0062 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -15.0441 - val_MultivariateLoss_loss: -17.3273 - val_MassOutput_loss: 1.0114 - val_MultivariateLoss_Mean_Squared_Error: 0.0227 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 95/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.4016 - MultivariateLoss_loss: -17.6756 - MassOutput_loss: 1.0062 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -14.2075 - val_MultivariateLoss_loss: -16.4786 - val_MassOutput_loss: 1.0112 - val_MultivariateLoss_Mean_Squared_Error: 0.0227 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 96/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.4308 - MultivariateLoss_loss: -17.6902 - MassOutput_loss: 1.0062 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -12.2420 - val_MultivariateLoss_loss: -14.5005 - val_MassOutput_loss: 1.0116 - val_MultivariateLoss_Mean_Squared_Error: 0.0231 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 97/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.4995 - MultivariateLoss_loss: -17.7452 - MassOutput_loss: 1.0060 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -14.9993 - val_MultivariateLoss_loss: -17.2443 - val_MassOutput_loss: 1.0116 - val_MultivariateLoss_Mean_Squared_Error: 0.0228 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 98/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.4653 - MultivariateLoss_loss: -17.6999 - MassOutput_loss: 1.0061 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2043 - val_loss: -14.5726 - val_MultivariateLoss_loss: -16.8059 - val_MassOutput_loss: 1.0116 - val_MultivariateLoss_Mean_Squared_Error: 0.0226 - val_MassOutput_Mean_Squared_Error: 0.2055 - lr: 3.0000e-04
# Epoch 99/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.5088 - MultivariateLoss_loss: -17.7303 - MassOutput_loss: 1.0060 - MultivariateLoss_Mean_Squared_Error: 0.0246 - MassOutput_Mean_Squared_Error: 0.2043 - val_loss: -11.6139 - val_MultivariateLoss_loss: -13.8356 - val_MassOutput_loss: 1.0117 - val_MultivariateLoss_Mean_Squared_Error: 0.0228 - val_MassOutput_Mean_Squared_Error: 0.2055 - lr: 3.0000e-04
# Epoch 100/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.5141 - MultivariateLoss_loss: -17.7237 - MassOutput_loss: 1.0061 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2043 - val_loss: -14.9656 - val_MultivariateLoss_loss: -17.1741 - val_MassOutput_loss: 1.0117 - val_MultivariateLoss_Mean_Squared_Error: 0.0228 - val_MassOutput_Mean_Squared_Error: 0.2055 - lr: 3.0000e-04
# Epoch 101/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.5112 - MultivariateLoss_loss: -17.7084 - MassOutput_loss: 1.0061 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -14.8591 - val_MultivariateLoss_loss: -17.0580 - val_MassOutput_loss: 1.0116 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2055 - lr: 3.0000e-04
# Epoch 102/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.5671 - MultivariateLoss_loss: -17.7537 - MassOutput_loss: 1.0061 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -14.6416 - val_MultivariateLoss_loss: -16.8287 - val_MassOutput_loss: 1.0117 - val_MultivariateLoss_Mean_Squared_Error: 0.0228 - val_MassOutput_Mean_Squared_Error: 0.2055 - lr: 3.0000e-04
# Epoch 103/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.5753 - MultivariateLoss_loss: -17.7511 - MassOutput_loss: 1.0060 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2043 - val_loss: -14.4503 - val_MultivariateLoss_loss: -16.6282 - val_MassOutput_loss: 1.0116 - val_MultivariateLoss_Mean_Squared_Error: 0.0226 - val_MassOutput_Mean_Squared_Error: 0.2054 - lr: 3.0000e-04
# Epoch 104/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.5958 - MultivariateLoss_loss: -17.7618 - MassOutput_loss: 1.0060 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2043 - val_loss: -13.8925 - val_MultivariateLoss_loss: -16.0589 - val_MassOutput_loss: 1.0117 - val_MultivariateLoss_Mean_Squared_Error: 0.0229 - val_MassOutput_Mean_Squared_Error: 0.2055 - lr: 3.0000e-04
# Epoch 105/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.6317 - MultivariateLoss_loss: -17.7867 - MassOutput_loss: 1.0061 - MultivariateLoss_Mean_Squared_Error: 0.0248 - MassOutput_Mean_Squared_Error: 0.2044 - val_loss: -14.3454 - val_MultivariateLoss_loss: -16.5027 - val_MassOutput_loss: 1.0116 - val_MultivariateLoss_Mean_Squared_Error: 0.0228 - val_MassOutput_Mean_Squared_Error: 0.2055 - lr: 3.0000e-04
# Epoch 106/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.6583 - MultivariateLoss_loss: -17.8033 - MassOutput_loss: 1.0060 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2043 - val_loss: -15.2111 - val_MultivariateLoss_loss: -17.3567 - val_MassOutput_loss: 1.0121 - val_MultivariateLoss_Mean_Squared_Error: 0.0225 - val_MassOutput_Mean_Squared_Error: 0.2055 - lr: 3.0000e-04
# Epoch 107/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.6529 - MultivariateLoss_loss: -17.7874 - MassOutput_loss: 1.0060 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2043 - val_loss: -15.0461 - val_MultivariateLoss_loss: -17.1811 - val_MassOutput_loss: 1.0117 - val_MultivariateLoss_Mean_Squared_Error: 0.0229 - val_MassOutput_Mean_Squared_Error: 0.2055 - lr: 3.0000e-04
# Epoch 108/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.6622 - MultivariateLoss_loss: -17.7861 - MassOutput_loss: 1.0060 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2043 - val_loss: -14.9407 - val_MultivariateLoss_loss: -17.0656 - val_MassOutput_loss: 1.0118 - val_MultivariateLoss_Mean_Squared_Error: 0.0229 - val_MassOutput_Mean_Squared_Error: 0.2055 - lr: 3.0000e-04
# Epoch 109/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.7194 - MultivariateLoss_loss: -17.8338 - MassOutput_loss: 1.0060 - MultivariateLoss_Mean_Squared_Error: 0.0248 - MassOutput_Mean_Squared_Error: 0.2043 - val_loss: -14.8540 - val_MultivariateLoss_loss: -16.9689 - val_MassOutput_loss: 1.0118 - val_MultivariateLoss_Mean_Squared_Error: 0.0229 - val_MassOutput_Mean_Squared_Error: 0.2055 - lr: 3.0000e-04
# Epoch 110/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -15.7197 - MultivariateLoss_loss: -17.8242 - MassOutput_loss: 1.0060 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2043 - val_loss: -13.9076 - val_MultivariateLoss_loss: -16.0132 - val_MassOutput_loss: 1.0119 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2055 - lr: 3.0000e-04
# Epoch 111/1000
# ...
# Epoch 204/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -17.0418 - MultivariateLoss_loss: -18.7639 - MassOutput_loss: 1.0051 - MultivariateLoss_Mean_Squared_Error: 0.0248 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -13.6040 - val_MultivariateLoss_loss: -15.3326 - val_MassOutput_loss: 1.0124 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2056 - lr: 1.2288e-04
# Epoch 205/1000
# 1058/1058 [==============================] - 22s 20ms/step - loss: -17.1173 - MultivariateLoss_loss: -18.8379 - MassOutput_loss: 1.0050 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -14.1966 - val_MultivariateLoss_loss: -15.9237 - val_MassOutput_loss: 1.0123 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2056 - lr: 9.8304e-05
# Epoch 206/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -17.1150 - MultivariateLoss_loss: -18.8342 - MassOutput_loss: 1.0049 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -13.8259 - val_MultivariateLoss_loss: -15.5517 - val_MassOutput_loss: 1.0123 - val_MultivariateLoss_Mean_Squared_Error: 0.0231 - val_MassOutput_Mean_Squared_Error: 0.2056 - lr: 9.8304e-05
# Epoch 207/1000
# 1058/1058 [==============================] - 22s 20ms/step - loss: -17.1377 - MultivariateLoss_loss: -18.8555 - MassOutput_loss: 1.0050 - MultivariateLoss_Mean_Squared_Error: 0.0248 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -14.5821 - val_MultivariateLoss_loss: -16.3067 - val_MassOutput_loss: 1.0124 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2056 - lr: 9.8304e-05
# Epoch 208/1000
# 1058/1058 [==============================] - 22s 20ms/step - loss: -17.1308 - MultivariateLoss_loss: -18.8472 - MassOutput_loss: 1.0050 - MultivariateLoss_Mean_Squared_Error: 0.0248 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -14.6245 - val_MultivariateLoss_loss: -16.3476 - val_MassOutput_loss: 1.0124 - val_MultivariateLoss_Mean_Squared_Error: 0.0229 - val_MassOutput_Mean_Squared_Error: 0.2056 - lr: 9.8304e-05
# Epoch 209/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -17.1366 - MultivariateLoss_loss: -18.8516 - MassOutput_loss: 1.0050 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -13.1141 - val_MultivariateLoss_loss: -14.8358 - val_MassOutput_loss: 1.0124 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2056 - lr: 9.8304e-05
# Epoch 210/1000
# 1058/1058 [==============================] - 22s 20ms/step - loss: -17.1484 - MultivariateLoss_loss: -18.8621 - MassOutput_loss: 1.0049 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -14.3427 - val_MultivariateLoss_loss: -16.0628 - val_MassOutput_loss: 1.0123 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2056 - lr: 9.8304e-05
# Epoch 211/1000
# 1058/1058 [==============================] - 22s 21ms/step - loss: -17.1496 - MultivariateLoss_loss: -18.8619 - MassOutput_loss: 1.0050 - MultivariateLoss_Mean_Squared_Error: 0.0248 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -13.8421 - val_MultivariateLoss_loss: -15.5611 - val_MassOutput_loss: 1.0124 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2057 - lr: 9.8304e-05
# Epoch 212/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -17.1470 - MultivariateLoss_loss: -18.8580 - MassOutput_loss: 1.0050 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -14.2320 - val_MultivariateLoss_loss: -15.9495 - val_MassOutput_loss: 1.0123 - val_MultivariateLoss_Mean_Squared_Error: 0.0231 - val_MassOutput_Mean_Squared_Error: 0.2056 - lr: 9.8304e-05
# Epoch 213/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -17.1488 - MultivariateLoss_loss: -18.8584 - MassOutput_loss: 1.0050 - MultivariateLoss_Mean_Squared_Error: 0.0248 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -12.8772 - val_MultivariateLoss_loss: -14.5939 - val_MassOutput_loss: 1.0126 - val_MultivariateLoss_Mean_Squared_Error: 0.0231 - val_MassOutput_Mean_Squared_Error: 0.2057 - lr: 9.8304e-05
# Epoch 214/1000
# 1058/1058 [==============================] - 22s 20ms/step - loss: -17.1592 - MultivariateLoss_loss: -18.8677 - MassOutput_loss: 1.0050 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -13.7051 - val_MultivariateLoss_loss: -15.4202 - val_MassOutput_loss: 1.0125 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2057 - lr: 9.8304e-05
# Epoch 215/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -17.1641 - MultivariateLoss_loss: -18.8711 - MassOutput_loss: 1.0049 - MultivariateLoss_Mean_Squared_Error: 0.0248 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -14.9368 - val_MultivariateLoss_loss: -16.6506 - val_MassOutput_loss: 1.0124 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2056 - lr: 9.8304e-05
# Epoch 216/1000
# 1058/1058 [==============================] - 22s 20ms/step - loss: -17.1681 - MultivariateLoss_loss: -18.8739 - MassOutput_loss: 1.0050 - MultivariateLoss_Mean_Squared_Error: 0.0248 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -14.2635 - val_MultivariateLoss_loss: -15.9761 - val_MassOutput_loss: 1.0124 - val_MultivariateLoss_Mean_Squared_Error: 0.0229 - val_MassOutput_Mean_Squared_Error: 0.2057 - lr: 9.8304e-05
# Epoch 217/1000
# 1058/1058 [==============================] - 22s 20ms/step - loss: -17.1666 - MultivariateLoss_loss: -18.8712 - MassOutput_loss: 1.0049 - MultivariateLoss_Mean_Squared_Error: 0.0248 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -14.0072 - val_MultivariateLoss_loss: -15.7185 - val_MassOutput_loss: 1.0124 - val_MultivariateLoss_Mean_Squared_Error: 0.0231 - val_MassOutput_Mean_Squared_Error: 0.2057 - lr: 9.8304e-05
# Epoch 218/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -17.1727 - MultivariateLoss_loss: -18.8759 - MassOutput_loss: 1.0049 - MultivariateLoss_Mean_Squared_Error: 0.0248 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -13.6241 - val_MultivariateLoss_loss: -15.3343 - val_MassOutput_loss: 1.0126 - val_MultivariateLoss_Mean_Squared_Error: 0.0231 - val_MassOutput_Mean_Squared_Error: 0.2057 - lr: 9.8304e-05
# Epoch 219/1000
# 1058/1058 [==============================] - 22s 20ms/step - loss: -17.1767 - MultivariateLoss_loss: -18.8788 - MassOutput_loss: 1.0050 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -14.1705 - val_MultivariateLoss_loss: -15.8793 - val_MassOutput_loss: 1.0124 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2056 - lr: 9.8304e-05
# Epoch 220/1000
# 1058/1058 [==============================] - 22s 20ms/step - loss: -17.2495 - MultivariateLoss_loss: -18.9503 - MassOutput_loss: 1.0048 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -13.5629 - val_MultivariateLoss_loss: -15.2706 - val_MassOutput_loss: 1.0124 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2057 - lr: 7.8643e-05
# Epoch 221/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -17.2507 - MultivariateLoss_loss: -18.9503 - MassOutput_loss: 1.0048 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -13.8521 - val_MultivariateLoss_loss: -15.5588 - val_MassOutput_loss: 1.0124 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2056 - lr: 7.8643e-05
# Epoch 222/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -17.2494 - MultivariateLoss_loss: -18.9480 - MassOutput_loss: 1.0048 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -14.2314 - val_MultivariateLoss_loss: -15.9372 - val_MassOutput_loss: 1.0124 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2057 - lr: 7.8643e-05
# Epoch 223/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -17.2556 - MultivariateLoss_loss: -18.9532 - MassOutput_loss: 1.0049 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -14.1704 - val_MultivariateLoss_loss: -15.8750 - val_MassOutput_loss: 1.0124 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2057 - lr: 7.8643e-05
# Epoch 224/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -17.2586 - MultivariateLoss_loss: -18.9553 - MassOutput_loss: 1.0048 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -14.4349 - val_MultivariateLoss_loss: -16.1385 - val_MassOutput_loss: 1.0124 - val_MultivariateLoss_Mean_Squared_Error: 0.0231 - val_MassOutput_Mean_Squared_Error: 0.2057 - lr: 7.8643e-05
# Epoch 225/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -17.2608 - MultivariateLoss_loss: -18.9563 - MassOutput_loss: 1.0048 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -14.0353 - val_MultivariateLoss_loss: -15.7378 - val_MassOutput_loss: 1.0124 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2057 - lr: 7.8643e-05
# Epoch 226/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -17.2587 - MultivariateLoss_loss: -18.9532 - MassOutput_loss: 1.0048 - MultivariateLoss_Mean_Squared_Error: 0.0248 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -14.2648 - val_MultivariateLoss_loss: -15.9666 - val_MassOutput_loss: 1.0125 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2057 - lr: 7.8643e-05
# Epoch 227/1000
# 1058/1058 [==============================] - 22s 20ms/step - loss: -17.2636 - MultivariateLoss_loss: -18.9571 - MassOutput_loss: 1.0048 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -13.8201 - val_MultivariateLoss_loss: -15.5209 - val_MassOutput_loss: 1.0125 - val_MultivariateLoss_Mean_Squared_Error: 0.0233 - val_MassOutput_Mean_Squared_Error: 0.2057 - lr: 7.8643e-05
# Epoch 228/1000
# 1058/1058 [==============================] - 22s 20ms/step - loss: -17.2671 - MultivariateLoss_loss: -18.9596 - MassOutput_loss: 1.0049 - MultivariateLoss_Mean_Squared_Error: 0.0248 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -13.3361 - val_MultivariateLoss_loss: -15.0357 - val_MassOutput_loss: 1.0124 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2056 - lr: 7.8643e-05
# Epoch 229/1000
# 1058/1058 [==============================] - 22s 20ms/step - loss: -17.2691 - MultivariateLoss_loss: -18.9607 - MassOutput_loss: 1.0048 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -13.7023 - val_MultivariateLoss_loss: -15.4010 - val_MassOutput_loss: 1.0125 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2057 - lr: 7.8643e-05
# Epoch 230/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -17.2769 - MultivariateLoss_loss: -18.9674 - MassOutput_loss: 1.0048 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -14.1302 - val_MultivariateLoss_loss: -15.8279 - val_MassOutput_loss: 1.0125 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2057 - lr: 7.8643e-05
# Epoch 231/1000
# 1058/1058 [==============================] - 22s 20ms/step - loss: -17.2783 - MultivariateLoss_loss: -18.9680 - MassOutput_loss: 1.0048 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -14.6624 - val_MultivariateLoss_loss: -16.3593 - val_MassOutput_loss: 1.0125 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2057 - lr: 7.8643e-05
# Epoch 232/1000
# 1058/1058 [==============================] - 22s 21ms/step - loss: -17.2858 - MultivariateLoss_loss: -18.9745 - MassOutput_loss: 1.0048 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -14.1964 - val_MultivariateLoss_loss: -15.8924 - val_MassOutput_loss: 1.0125 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2057 - lr: 7.8643e-05
# Epoch 233/1000
# 1058/1058 [==============================] - 22s 21ms/step - loss: -17.2850 - MultivariateLoss_loss: -18.9727 - MassOutput_loss: 1.0048 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -13.9818 - val_MultivariateLoss_loss: -15.6767 - val_MassOutput_loss: 1.0124 - val_MultivariateLoss_Mean_Squared_Error: 0.0231 - val_MassOutput_Mean_Squared_Error: 0.2056 - lr: 7.8643e-05
# Epoch 234/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -17.2910 - MultivariateLoss_loss: -18.9777 - MassOutput_loss: 1.0048 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -14.0649 - val_MultivariateLoss_loss: -15.7588 - val_MassOutput_loss: 1.0125 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2057 - lr: 7.8643e-05
# Epoch 235/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -17.3421 - MultivariateLoss_loss: -19.0279 - MassOutput_loss: 1.0048 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -14.4157 - val_MultivariateLoss_loss: -16.1088 - val_MassOutput_loss: 1.0125 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2057 - lr: 6.2915e-05
# Epoch 236/1000
# 1058/1058 [==============================] - 22s 20ms/step - loss: -17.3476 - MultivariateLoss_loss: -19.0326 - MassOutput_loss: 1.0048 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -14.4147 - val_MultivariateLoss_loss: -16.1071 - val_MassOutput_loss: 1.0125 - val_MultivariateLoss_Mean_Squared_Error: 0.0231 - val_MassOutput_Mean_Squared_Error: 0.2057 - lr: 6.2915e-05
# Epoch 237/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -17.3506 - MultivariateLoss_loss: -19.0349 - MassOutput_loss: 1.0047 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -14.2723 - val_MultivariateLoss_loss: -15.9637 - val_MassOutput_loss: 1.0124 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2056 - lr: 6.2915e-05
# Epoch 238/1000
# 1058/1058 [==============================] - 22s 20ms/step - loss: -17.3433 - MultivariateLoss_loss: -19.0268 - MassOutput_loss: 1.0048 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -13.4424 - val_MultivariateLoss_loss: -15.1331 - val_MassOutput_loss: 1.0125 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2057 - lr: 6.2915e-05
# Epoch 239/1000
# 1058/1058 [==============================] - 21s 20ms/step - loss: -17.3596 - MultivariateLoss_loss: -19.0423 - MassOutput_loss: 1.0047 - MultivariateLoss_Mean_Squared_Error: 0.0247 - MassOutput_Mean_Squared_Error: 0.2041 - val_loss: -13.6151 - val_MultivariateLoss_loss: -15.3051 - val_MassOutput_loss: 1.0125 - val_MultivariateLoss_Mean_Squared_Error: 0.0230 - val_MassOutput_Mean_Squared_Error: 0.2057 - lr: 6.2915e-05

# %%
# Plot the loss and validation curves vs epoch
history_df = pd.DataFrame(history.history)
(history_df.loc[:, ["loss","val_loss"]]).plot()
history_df.to_csv('/home/physics/phujdj/DeepLearningParticlePhysics/historyResidualNeuralNetwork.csv')
DeepSetProjector.save_weights("/home/physics/phujdj/DeepLearningParticlePhysics/CheckPointsDeepNet/ResidualDeepSetsWeights&BiasesFixUpdated3.ckpt")

# %%
#Evaluate the entire performance of the model
loss = DeepSetProjector.evaluate((particles_input_scaled,b_jets_input_scaled),(bhads_targets, onehot),verbose = 2)
print("The Loaded DeepNet has loss: ", loss)
# Out:
# 3021/3021 - 13s - loss: -1.6538e+01 - MultivariateLoss_loss: -1.8286e+01 - MassOutput_loss: 1.0070 - MultivariateLoss_Mean_Squared_Error: 0.0241 - MassOutput_Mean_Squared_Error: 0.2045 - 13s/epoch - 4ms/step
# The Loaded DeepNet has loss:  [-16.53771209716797, -18.285667419433594, 1.0070375204086304, 0.024120915681123734, 0.20454014837741852]

# %%
predictions = DeepSetProjector.predict((particles_input_scaled, b_jets_input_scaled))
# Out:
# 3021/3021 [==============================] - 12s 4ms/step

# %%
Predictions = predictions[0]
Predictions_Mass = predictions[1]

# %%
lister = []
index = 0
predictions_x = Predictions[:,:np.shape(bhads_targets)[1]]
predictions_X = predictions_x
predictions_x_uncertainty = Predictions[:,np.shape(bhads_targets)[1]:2*np.shape(bhads_targets)[1]]
Predictions_Uncertainty = predictions_x_uncertainty

# %%
np.save("/home/physics/phujdj/DeepLearningParticlePhysics/PredictionsMeans,npy", predictions_X)
np.save("/home/physics/phujdj/DeepLearningParticlePhysics/PredictionsUncertainties.npy", predictions_x_uncertainty)

# %%
Error_px_unscaled = (bhads_targets[:,0] - predictions_X[:,0])*1e6
Pull_bhads_px_unscaled = Error_px_unscaled/np.std(bhads_targets[:,0]*1e6)
Pull_px = Error_px_unscaled/(Predictions_Uncertainty[:,0]*1e6)

# %%
Error_py_unscaled = (bhads_targets[:,1] - predictions_X[:,1])*1e6
Pull_bhads_py_unscaled = Error_py_unscaled/np.std(bhads_targets[:,1]*1e6)
Pull_py = Error_py_unscaled/(Predictions_Uncertainty[:,1]*1e6)

# %%
Error_pz_unscaled = (bhads_targets[:,2] - predictions_X[:,2])*1e6
Pull_bhads_pz_unscaled = Error_pz_unscaled/np.std(bhads_targets[:,2]*1e6)
Pull_pz = Error_pz_unscaled/(Predictions_Uncertainty[:,2]*1e6)

# %%
Error_pt_unscaled = (bhads_targets[:,3] - predictions_X[:,3])*1e6
Pull_bhads_pt_unscaled = Error_pt_unscaled/np.std(bhads_targets[:,3]*1e6)
Pull_pt = Error_pt_unscaled/(Predictions_Uncertainty[:,3]*1e6)

# %%
Error_eta_unscaled = bhads_targets[:,4] - predictions_X[:,4]
Pull_bhads_eta_unscaled = Error_eta_unscaled/np.std(bhads_targets[:,4])
Pull_eta = Error_eta_unscaled/Predictions_Uncertainty[:,4]

# %%
Error_phi_unscaled = bhads_targets[:,5] - predictions_X[:,5]
Pull_bhads_pt_unscaled = Error_pt_unscaled/np.std(bhads_targets[:,5])
Pull_phi = Error_phi_unscaled/Predictions_Uncertainty[:,5]

# %%
Error_energy_unscaled = (bhads_targets[:,6] - predictions_X[:,6])*1e6
Pull_energy_unscaled = Error_energy_unscaled/np.std(bhads_targets[:,6]*1e6)
Pull_energy = Error_energy_unscaled/(Predictions_Uncertainty[:,6]*1e6)

# %%
Error_ptfraction_unscaled = bhads_targets[:,7] - predictions_X[:,7]
Pull_ptfraction_unscaled = Error_ptfraction_unscaled/np.std(bhads_targets[:,7])
Pull_ptfraction = Error_ptfraction_unscaled/Predictions_Uncertainty[:,7]

# %%
Error_projection_unscaled = bhads_targets[:,8] - predictions_X[:,8]
Pull_bhads_projection_unscaled = Error_projection_unscaled/np.std(bhads_targets[:,8])
Pull_projection = Error_projection_unscaled/Predictions_Uncertainty[:,8]

# %%
binneddensity(predictions_X[:,0]*1e6,fixedbinning(-5e5,5e5,100), xlabel = "Px")

# %%
print(np.mean(Error_px_unscaled))
print(np.std(Error_px_unscaled))
binneddensity(Error_px_unscaled, fixedbinning(-20000,20000,100),xlabel = "Error_px_unscaled")
# Out:
# 471.3371863378137
# 15569.606574569645

# %%
print(np.mean(Pull_px))
print(np.std(Pull_px))
binneddensity(Pull_px, fixedbinning(-2,2,100),xlabel = "Pull_Px")
# Out:
# 0.06309170850983394
# 0.8907582602093246

# %%
print(np.mean(Error_py_unscaled))
print(np.std(Error_py_unscaled))
binneddensity(Error_py_unscaled, fixedbinning(-20000,20000,100),xlabel = "Error_py_unscaled")
# Out:
# 722.4954915763154
# 15409.958651920837

# %%
print(np.mean(Pull_py))
print(np.std(Pull_py))
binneddensity(Pull_py, fixedbinning(-2,2,100),xlabel = "Pull_Py")
# Out:
# 0.1030308331788892
# 0.9256124779506691

# %%
print(np.mean(Error_pz_unscaled))
print(np.std(Error_pz_unscaled))
binneddensity(Error_pz_unscaled, fixedbinning(-40000,40000,100),xlabel = "Error_pz_unscaled")
# Out:
# -199.23402616601516
# 46793.52518826719

# %%
print(np.mean(Pull_pz))
print(np.std(Pull_pz))
binneddensity(Pull_pz, fixedbinning(-2,2,100),xlabel = "Pull_Pz")
# Out:
# 0.024189539957734988
# 0.9270644353449705

# %%
print(np.mean(Error_projection_unscaled))
print(np.std(Error_projection_unscaled))
binneddensity(Error_projection_unscaled, fixedbinning(-1,1,100),xlabel = "Error_projection")
# Out:
# -0.004033344393799809
# 0.1786409955174633

# %%
print(np.mean(Pull_projection))
print(np.std(Pull_projection))
binneddensity(Pull_projection, fixedbinning(-2,2,100),xlabel = "Pull_projection")
# Out:
# -0.023737532043809077
# 1.0000847469590521

# %%
print(np.mean(Error_ptfraction_unscaled))
print(np.std(Error_ptfraction_unscaled))
binneddensity(Error_ptfraction_unscaled, fixedbinning(-1,1,100),xlabel = "Error_pt_fraction")
# Out:
# 0.005372567128478266
# 0.1756165498059392

# %%
print(np.mean(Pull_ptfraction_unscaled))
print(np.std(Pull_ptfraction_unscaled))
binneddensity(Pull_ptfraction_unscaled, fixedbinning(-2,2,100),xlabel = "Pull_pt_fraction")
# Out:
# 0.0217857633452789
# 0.7121252284232029

# %%
print(np.mean(Error_energy_unscaled))
print(np.std(Error_energy_unscaled))
binneddensity(Error_energy_unscaled, fixedbinning(-40000,40000,100),xlabel = "Error_energy")
# Out:
# 691.986033743184
# 51015.88682106005

# %%
print(np.mean(Pull_energy_unscaled))
print(np.std(Pull_energy_unscaled))
binneddensity(Pull_energy_unscaled, fixedbinning(-1,1,100),xlabel = "Pull_energy_fraction")
# Out:
# 0.004648929876892387
# 0.34273709131911045

# %%
print(np.mean(Error_pt_unscaled))
print(np.std(Error_pt_unscaled))
binneddensity(Error_pt_unscaled, fixedbinning(-40000,40000,100),xlabel = "Error_pt")
# Out:
# -163.8661835434275
# 21468.474015760097

# %%
print(np.mean(Pull_pt))
print(np.std(Pull_pt))
binneddensity(Pull_pt, fixedbinning(-2,2,100),xlabel = "Pull_pt")
# Out:
# -0.0217477094365554
# 0.9174574323177871

# %%
print(np.mean(Error_eta_unscaled))
print(np.std(Error_eta_unscaled))
binneddensity(Error_eta_unscaled, fixedbinning(-0.1,0.1,100),xlabel = "Error_eta")
# Out:
# -0.0020118929958506697
# 0.05824323520033832

# %%
print(np.mean(Pull_eta))
print(np.std(Pull_eta))
binneddensity(Pull_eta, fixedbinning(-3,3,100),xlabel = "Pull_eta")
# Out:
# -0.033435420996522275
# 0.9763992406007093

# %%
print(np.mean(Error_phi_unscaled))
print(np.std(Error_phi_unscaled))
binneddensity(Error_phi_unscaled, fixedbinning(-0.1,0.1,100),xlabel = "Error_phi")
# Out:
# 0.0019920078738514917
# 0.38281589478544753

# %%
print(np.mean(Pull_phi))
print(np.std(Pull_phi))
binneddensity(Pull_phi, fixedbinning(-3,3,100),xlabel = "Pull_phi")
# Out:
# 0.07441796444238025
# 1.1084476740529365

# %%
import matplotlib as mpl
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde
fig, ax = plt.subplots(figsize = (12,12))
x = bhads_targets[:,0]*1e6
y = predictions_X[:,0]*1e6
grid = np.vstack([x, y])
z = gaussian_kde(grid)(grid)
idx = z.argsort()
x,y,z = x[idx], y[idx], z[idx]

im = sns.scatterplot(
    x,
    y,
    c = z,
    s = 5,
    cmap = "autumn",
    )
norm = plt.Normalize(z.min(), z.max())
sm = plt.cm.ScalarMappable(cmap = "autumn", norm = norm)
sm.set_array([])
im.figure.colorbar(sm)
ax.set_title("Scatterplot of the true vs pred X momenta")
ax.set_xlabel("The true X momenta of the tracks from each event")
ax.set_ylabel("The predicted X momenta of b hadron jets")
# Out:
# /home/physics/phujdj/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'The predicted X momenta of b hadron jets')

# %%
import matplotlib as mpl
from scipy.stats import gaussian_kde
fig, ax = plt.subplots(figsize = (12,12))
x = bhads_targets[:,1]*1e6
y = predictions_X[:,1]*1e6
grid = np.vstack([x, y])
z = gaussian_kde(grid)(grid)
idx = z.argsort()
x,y,z = x[idx], y[idx], z[idx]

im = sns.scatterplot(
    x,
    y,
    c = z,
    s = 5,
    cmap = "inferno",
    )
norm = plt.Normalize(z.min(), z.max())
sm = plt.cm.ScalarMappable(cmap = "inferno", norm = norm)
sm.set_array([])
im.figure.colorbar(sm)
ax.set_title("Scatterplot of the true vs pred Y momenta")
ax.set_xlabel("The true Y momenta of the b-hadrons from each event")
ax.set_ylabel("The predicted Y momenta of b hadron jets")
# Out:
# /home/physics/phujdj/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'The predicted Y momenta of b hadron jets')

# %%
import matplotlib as mpl
from scipy.stats import gaussian_kde
fig, ax = plt.subplots(figsize = (12,12))
x = bhads_targets[:,2]*1e6
y = predictions_X[:,2]*1e6
grid = np.vstack([x, y])
z = gaussian_kde(grid)(grid)
idx = z.argsort()
x,y,z = x[idx], y[idx], z[idx]

im = sns.scatterplot(
    x,
    y,
    c = z,
    s = 5,
    cmap = "winter",
    )
norm = plt.Normalize(z.min(), z.max())
sm = plt.cm.ScalarMappable(cmap = "winter", norm = norm)
sm.set_array([])
im.figure.colorbar(sm)
ax.set_title("Scatterplot of the true vs pred Z momenta")
ax.set_xlabel("The true Z momenta of the b-hadrons from each event")
ax.set_ylabel("The predicted Z momenta of b hadron jets")
# Out:
# /home/physics/phujdj/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'The predicted Z momenta of b hadron jets')

# %%
import matplotlib as mpl
from scipy.stats import gaussian_kde
fig, ax = plt.subplots(figsize = (12,12))
x = bhads_targets[:,3]*1e6
y = predictions_X[:,3]*1e6
grid = np.vstack([x, y])
z = gaussian_kde(grid)(grid)
idx = z.argsort()
x,y,z = x[idx], y[idx], z[idx]

im = sns.scatterplot(
    x,
    y,
    c = z,
    s = 5,
    cmap = "spring",
    )
norm = plt.Normalize(z.min(), z.max())
sm = plt.cm.ScalarMappable(cmap = "spring", norm = norm)
sm.set_array([])
im.figure.colorbar(sm)
ax.set_title("Scatterplot of the true vs pred transverse momenta")
ax.set_xlabel("The true tranvserse momenta of the b-hadrons from each event")
ax.set_ylabel("The predicted transverse momenta of b hadron jets")
# Out:
# /home/physics/phujdj/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'The predicted transverse momenta of b hadron jets')

# %%
import matplotlib as mpl
from scipy.stats import gaussian_kde
fig, ax = plt.subplots(figsize = (12,12))
x = bhads_targets[:,4]
y = predictions_X[:,4]
grid = np.vstack([x, y])
z = gaussian_kde(grid)(grid)
idx = z.argsort()
x,y,z = x[idx], y[idx], z[idx]

im = sns.scatterplot(
    x,
    y,
    c = z,
    s = 5,
    cmap = "gist_heat",
    )
norm = plt.Normalize(z.min(), z.max())
sm = plt.cm.ScalarMappable(cmap = "gist_heat", norm = norm)
sm.set_array([])
im.figure.colorbar(sm)
ax.set_title("Scatterplot of the true vs pred pseudorapidity")
ax.set_xlabel("The true pseudorapidity of the b-hadrons from each event")
ax.set_ylabel("The predicted pseudorapidity of b hadron jets")
# Out:
# /home/physics/phujdj/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'The predicted pseudorapidity of b hadron jets')

# %%
import matplotlib as mpl
from scipy.stats import gaussian_kde
fig, ax = plt.subplots(figsize = (12,12))
x = bhads_targets[:,5]
y = predictions_X[:,5]
grid = np.vstack([x, y])
z = gaussian_kde(grid)(grid)
idx = z.argsort()
x,y,z = x[idx], y[idx], z[idx]

im = sns.scatterplot(
    x,
    y,
    c = z,
    s = 5,
    cmap = "summer",
    )
norm = plt.Normalize(z.min(), z.max())
sm = plt.cm.ScalarMappable(cmap = "summer", norm = norm)
sm.set_array([])
im.figure.colorbar(sm)
ax.set_title("Scatterplot of the true vs pred phi")
ax.set_xlabel("The true phi of the b-hadrons from each event")
ax.set_ylabel("The predicted phi of b hadron jets")
# Out:
# /home/physics/phujdj/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'The predicted phi of b hadron jets')

# %%
import matplotlib as mpl
from scipy.stats import gaussian_kde
fig, ax = plt.subplots(figsize = (12,12))
x = bhads_targets[:,7]
y = predictions_X[:,7]
grid = np.vstack([x, y])
z = gaussian_kde(grid)(grid)
idx = z.argsort()
x,y,z = x[idx], y[idx], z[idx]

im = sns.scatterplot(
    x,
    y,
    c = z,
    s = 5,
    cmap = "spring",
    )
norm = plt.Normalize(z.min(), z.max())
sm = plt.cm.ScalarMappable(cmap = "spring", norm = norm)
sm.set_array([])
im.figure.colorbar(sm)
ax.set_xlim([0,1.5])
ax.set_title("Scatterplot of the true vs pred pt momenta fraction")
ax.set_xlabel("The true pt momenta fraction of the b-hadrons from each event")
ax.set_ylabel("The predicted pt fraction of b hadron jets")
# Out:
# /home/physics/phujdj/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'The predicted pt fraction of b hadron jets')

# %%
import matplotlib as mpl
from scipy.stats import gaussian_kde
fig, ax = plt.subplots(figsize = (12,12))
x = bhads_targets[:,8]
y = predictions_X[:,8]
grid = np.vstack([x, y])
z = gaussian_kde(grid)(grid)
idx = z.argsort()
x,y,z = x[idx], y[idx], z[idx]

im = sns.scatterplot(
    x,
    y,
    c = z,
    s = 5,
    cmap = "gist_heat",
    )
norm = plt.Normalize(z.min(), z.max())
sm = plt.cm.ScalarMappable(cmap = "gist_heat", norm = norm)
sm.set_array([])
im.figure.colorbar(sm)
ax.set_xlim([0,1.5])
ax.set_title("Scatterplot of the true vs pred projection of bhadron momenta")
ax.set_xlabel("The true pred momenta projection of the b-hadrons from each event")
ax.set_ylabel("The predicted momenta projection of b hadron jets")
# Out:
# /home/physics/phujdj/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'The predicted momenta projection of b hadron jets')

# %%
import matplotlib as mpl
from scipy.stats import gaussian_kde
fig, ax = plt.subplots(figsize = (12,12))
x = bhads_targets[:,6]*1e6
y = predictions_X[:,6]*1e6
grid = np.vstack([x, y])
z = gaussian_kde(grid)(grid)
idx = z.argsort()
x,y,z = x[idx], y[idx], z[idx]

im = sns.scatterplot(
    x,
    y,
    c = z,
    s = 5,
    cmap = "PiYG",
    )
norm = plt.Normalize(z.min(), z.max())
sm = plt.cm.ScalarMappable(cmap = "PiYG", norm = norm)
sm.set_array([])
im.figure.colorbar(sm)
ax.set_xlim([0,2e6])
ax.set_title("Scatterplot of the true vs pred Bhadron energy")
ax.set_xlabel("The true Bhadron energy of the b-hadrons from each event")
ax.set_ylabel("The predicted Bhadron energy of b hadron jets")
# Out:
# /home/physics/phujdj/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'The predicted Bhadron energy of b hadron jets')

# %%
DeepSetProjector.save_weights("/home/physics/phujdj/WeightsSaved/MultivariateParticleDeepSets.ckpt")

# %%
# Builds the deep neural network
track_layers = [64 for x in range(2)]
jet_layers = [100 for x in range(3)]
b_jets_layers = [64 for x in range(2)]

track_layers = [np.shape(particles_input_scaled)[2]]+track_layers
print(track_layers)
print(np.shape(onehot)[1])
#Initializers the optimizer used for training the network
optimizer = tf.keras.optimizers.Nadam(LR)

#Build a DeepSets Projection Neural Network
DeepSetProjector2 = DeepSetsProjection(track_layers=track_layers, b_jet_layers= b_jets_layers, jet_layers=jet_layers, n_targets=np.shape(bhads_targets)[1], n_targets_classification= np.shape(onehot)[1], regularizer_strength= 1e-4, n_features=np.shape(b_jets_input_scaled)[1], Dropout_rate=0.1)
# Out:
# [15, 64, 64]
# 3

# %%
from DeepSetNeuralNetArchitecture import LogNormal_Loss_Function
from HffragDeepSetsProjection import Multivariate_Gaussian_Negative_Likelihood_Loss_Curve
from HffragDeepSetsProjectionMultivariate import weighted_categorical_crossentropy
DeepSetProjector2.compile(
 optimizer = optimizer,
 loss = {"MultivariateLoss": Multivariate_Gaussian_Negative_Likelihood_Loss_Curve, "MassOutput":tf.keras.losses.categorical_crossentropy},
 metrics = [Mean_Squared_Error]   
)

# %%
path = "/home/physics/phujdj/WeightsSaved/MultivariateParticleDeepSets.ckpt"
checkpoint = os.path.dirname(path)
latest_DeepNet = tf.train.latest_checkpoint(checkpoint)

# %%
DeepSetProjector2.load_weights(latest_DeepNet)

# %%
#Evaluate the entire performance of the model
loss = DeepSetProjector2.evaluate((particles_input_scaled,b_jets_input_scaled),(bhads_targets, onehot),verbose = 2)
print("The Loaded DeepNet has loss: ", loss)
# Out:
# 3021/3021 - 13s - loss: -1.6538e+01 - MultivariateLoss_loss: -1.8286e+01 - MassOutput_loss: 1.0070 - MultivariateLoss_Mean_Squared_Error: 0.0241 - MassOutput_Mean_Squared_Error: 0.2045 - 13s/epoch - 4ms/step
# The Loaded DeepNet has loss:  [-16.53771209716797, -18.285667419433594, 1.0070375204086304, 0.024120915681123734, 0.20454014837741852]

# %%
from sklearn.metrics import confusion_matrix
from sklearn import metrics
confusion_mat = confusion_matrix(np.argmax(onehot, axis = 1), np.argmax(Predictions_Mass,axis = 1))
confusion_visualized = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_mat)
confusion_visualized.plot()
